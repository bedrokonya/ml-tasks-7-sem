# %% [markdown]
# <span style="font-size: 14pt">MIPT, Applied ML, Autumn 2018</span>
#
# <span style="font-size: 16pt"> HW#1 </span>
#
# <span style="color:red; font-size: 16pt"> deadline: 22.09.2018 23:59 </span>
#
# <span style="color:blue; font-size: 12pt">Alexey Romanenko </span>,
# <span style="color:blue; font-size: 12pt; font-family: 'Verdana'">alexromsput@gmail.com</span>

# %% [markdown]
# <h1 align="center">Organization Info</h1>

# %% [markdown]
# **Дополнительный материал для выполнения дз**:
# - Лукашин Ю.П. Адаптивные методы краткосрочного прогнозирования временных рядов. Финансы и статистика. 2003, главы 1,4,5,7.
# - Магнус Я.Р., Катышев П.К., Пересецкий А.А. Эконометрика. Начальный курс., глава 11
#
# **Оформление дз**:
# - Выполненное задание требуется отправлять через <a href='https://goo.gl/forms/XPSIbwp7wPxB4SsI3'>форму </a>
#     - <span style="color:red; font-size: 20pt">ВНИМАНИЕ: для отправки задания потребуется почта в домене gmail.com или phystech.edu</span>
#
# - Укажите тему письма в следующем формате ``ML2018_fall_<номер_группы>_<фамилия>``, к примеру -- ``ML2018_fall_594_ivanov``
# - Выполненное дз сохраните в файл ``<фамилия>_<группа>_task<номер>.ipynb``, к примеру -- ``ivanov_401_task1.ipynb``
#
# **Вопросы**:
# - Вопросы присылайте на почту ml.course.mipt@gmail.com
# - Укажите тему письма в следующем формате ``ML2018_fall_Question_<Тема вопроса>``
#
# --------
# - **PS1**: Будьте внимательны при заполнении формы, когда отправляете ДЗ

# %% [markdown]
# <h1 align="center">Теоретическая часть (15%)</h1>

# %% [markdown]
# Ответе на вопросы своими словами (загугленный материал надо пересказать), ответ обоснуйте (напишите и ОБЪЯСНИТЕ формулки если потребуется), если не выходит, то вернитесь к лекции дополнительным материалам:
#
# **Вопрос 1**: Пусть дан временной ряд $y_t = \delta\cdot t + \varepsilon_t$, где $\varepsilon_t$ - случайная величина с нулевым матожиданием и не зависящей от времени дисперсией $\sigma$, $E \varepsilon_t \varepsilon_{t+k}=0$ при $k\not=0$, Докажите, что оптимальное значение параметра сглаживания $\alpha$ в алгоритме простого экспоненциального сглаживания для такого временного ряда будет равно 1.
#
# <Ответ>
#
# **Вопрос 2**: Докажите  эквивалетность формул расчёта (в рекуррентной форме и в форме корректировки прогноза (correction error form) )скрытых компонент временного ряда для модели линейного затухающего тренда:
#
# $$ l_{t}= \alpha y_t + \left(1-\alpha\right) \left(l_{t-1} +\phi b_{t-1}\right)\color{red}{=}l_{t-1} +\phi b_{t-1} + \alpha e_t$$,
# $$ b_t         = \beta \left(l_t - l_{t-1}\right) + \left(1-\beta\right)\phi b_{t-1}\color{red}{=}\phi b_{t-1} +  \alpha\beta e_t.$$
#
# <Ответ>
#
# **Вопрос 3**: Выведите формулу расчёта скрытых компонент в форме корректировки прогноза (correction error form) временного ряда в модели ЭС с мультипликативным затухающим трендом (WS with multiplicative damped trend):
#
# ### \begin{align*}
# 		\hat{y}_{t+d|t} &= l_t b_t^{\left(\phi + \phi^2 + \dots + \phi^{d}\right)}, \\
# 		l_{t}       &= \alpha y_t + \left(1-\alpha\right) l_{t-1} b_{t-1}^{\phi}, \\
# 		b_t         &= \beta\frac{l_t}{l_{t-1}} + \left(1-\beta\right)b_{t-1}^{\phi}.
# \end{align*}
#
#
# <Ответ>
#
# -----------
# PS: Если проверяющий не понял ответ на большинство вопросов, то будет пичалька. Пишите так, чтобы можно было разобраться.

# %% [markdown]
# <h1 align="center"> Реализация алгоритма из семейства ES (85%) </h1>
#
# Суть задания: реализовать, применить на данных monthly_wage модель Уинтерса с линейным трендом.
# ## $$\hat y_{t+d} = (l_t + b_t d) \cdot s_{t + (d \bmod p) -p}.$$
# Результат нужно сравнить с прогнозом модели Тейла-Вейджа.

# %%
# start with this code
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils import TheilWageExponentialSmoothing, build_forecast, plot_tsforecast
from utils import qualityRMSE, qualityMedianAE, qualityMACAPE, qualitySSE, qualityMSE, qualityMAPE 

# %matplotlib inline


wage = pd.read_csv('monthly-wage.csv', sep=';', decimal='.', index_col=0, parse_dates=True, dayfirst=True)

# Put your code below
wage.plot(figsize=(15,5))

# %% [markdown]
# # 1. Build the Forecast with Theil-Wage Model (25%)
#
# You need to apply Theil-Wage (TWES) model (see seminar 1) for the TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.
#
#
# * 0) Forecast Wage TS with Theil-Wage $\alpha=.1, \beta=0.3, \gamma=0.3$.
# * 1) Find the best param $\alpha, \beta, \gamma$ of Theil-Wage for data period from 09.1998 to 01.2015.
# * 2) Draw the forecast that correspond to TWES with optimial value $\alpha$ (use time steps from 09.1998 to 01.2017.)
#      Conclude whether TWES can be used for this TS? If can not than explain why.
# * 3) Calculate loss of the forecast of TS in [02.2015, 01.2017]. (You can choose any Loss function from seminar 1).

# %% [markdown]
# ## 1) Search for the optimal $\alpha$, $\beta$, $\gamma$ (10%)

# %%
wage[0:10]
# Out:
#             Real wage
# Month
# 1993-01-01     100.00
# 1993-02-01      99.04
# 1993-03-01     101.77
# 1993-04-01     110.05
# 1993-05-01     115.47
# 1993-06-01     120.65
# 1993-07-01     116.38
# 1993-08-01     107.85
# 1993-09-01     108.93
# 1993-10-01     103.39

# %%
ALPHA = np.linspace(0.0, 1.0, 20)
BETA = np.linspace(0.0, 1.0, 20)
GAMMA = np.linspace(0.0, 1.0, 20)
twes_params_array = [{'beta':beta, 'gamma':gamma, 'alpha':alpha, 'AdaptationPeriod':10, 'seasonality_period':12} for gamma in GAMMA for beta in BETA for alpha in ALPHA]
TWES_FRC_TS = build_forecast(h=1, ts=wage, algname = 'TheilWageExponentialSmoothing', algtitle='TWES', params_array = twes_params_array, step='M')

# %%
# find best TWES parameters
QualityStr = pd.DataFrame(index = wage.columns, columns = TWES_FRC_TS.keys())

ix = wage.loc['1998-09':'2015-01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = TWES_FRC_TS[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[ix], frc_wage.loc[ix])

QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# TWES {'beta': 0.0, 'gamma': 1.0, 'alpha': 0.5789473684210527, 'AdaptationPeriod': 10, 'seasonality_period': 12}                                     0.024948
# TWES {'beta': 0.0, 'gamma': 0.9473684210526315, 'alpha': 0.5789473684210527, 'AdaptationPeriod': 10, 'seasonality_period': 12}                      0.025184
# TWES {'beta': 0.0, 'gamma': 1.0, 'alpha': 0.631578947368421, 'AdaptationPeriod': 10, 'seasonality_period': 12}                                      0.025344
# TWES {'beta': 0.0, 'gamma': 1.0, 'alpha': 0.5263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}                                     0.025396
# TWES {'beta': 0.0, 'gamma': 0.9473684210526315, 'alpha': 0.5263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}                      0.025402
# TWES {'beta': 0.0, 'gamma': 0.894736842105263, 'alpha': 0.5789473684210527, 'AdaptationPeriod': 10, 'seasonality_period': 12}                       0.025471
# TWES {'beta': 0.0, 'gamma': 0.894736842105263, 'alpha': 0.5263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}                       0.025545
# TWES {'beta': 0.05263157894736842, 'gamma': 1.0, 'alpha': 0.5263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}                     0.025578
# TWES {'beta': 0.0, 'gamma': 0.9473684210526315, 'alpha': 0.631578947368421, 'AdaptationPeriod': 10, 'seasonality_period': 12}                       0.025637
# TWES {'beta': 0.05263157894736842, 'gamma': 0.9473684210526315, 'alpha': 0.5263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}      0.025681
# TWES {'beta': 0.0, 'gamma': 0.8421052631578947, 'alpha': 0.5263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}                      0.025786
# TWES {'beta': 0.05263157894736842, 'gamma': 0.9473684210526315, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}     0.025801
# TWES {'beta': 0.0, 'gamma': 0.8421052631578947, 'alpha': 0.5789473684210527, 'AdaptationPeriod': 10, 'seasonality_period': 12}                      0.025815
# TWES {'beta': 0.05263157894736842, 'gamma': 0.894736842105263, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}      0.025816
# TWES {'beta': 0.05263157894736842, 'gamma': 0.894736842105263, 'alpha': 0.5263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}       0.025818
# TWES {'beta': 0.05263157894736842, 'gamma': 0.8421052631578947, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}     0.025826
# TWES {'beta': 0.05263157894736842, 'gamma': 1.0, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}                    0.025889
# TWES {'beta': 0.05263157894736842, 'gamma': 0.7894736842105263, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}     0.025951
# TWES {'beta': 0.0, 'gamma': 0.7894736842105263, 'alpha': 0.5263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}                      0.026017
# TWES {'beta': 0.0, 'gamma': 0.894736842105263, 'alpha': 0.631578947368421, 'AdaptationPeriod': 10, 'seasonality_period': 12}                        0.026028
# TWES {'beta': 0.05263157894736842, 'gamma': 0.8421052631578947, 'alpha': 0.5263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}      0.026103
# TWES {'beta': 0.0, 'gamma': 0.9473684210526315, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}                     0.026115
# TWES {'beta': 0.0, 'gamma': 1.0, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}                                    0.026125
# TWES {'beta': 0.05263157894736842, 'gamma': 1.0, 'alpha': 0.5789473684210527, 'AdaptationPeriod': 10, 'seasonality_period': 12}                     0.026153
# TWES {'beta': 0.05263157894736842, 'gamma': 0.7368421052631579, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}     0.026172
# TWES {'beta': 0.0, 'gamma': 0.894736842105263, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}                      0.026176
# TWES {'beta': 0.0, 'gamma': 0.7894736842105263, 'alpha': 0.5789473684210527, 'AdaptationPeriod': 10, 'seasonality_period': 12}                      0.026223
# TWES {'beta': 0.0, 'gamma': 0.8421052631578947, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}                     0.026263
# TWES {'beta': 0.05263157894736842, 'gamma': 0.7894736842105263, 'alpha': 0.42105263157894735, 'AdaptationPeriod': 10, 'seasonality_period': 12}     0.026289
# TWES {'beta': 0.05263157894736842, 'gamma': 0.8421052631578947, 'alpha': 0.42105263157894735, 'AdaptationPeriod': 10, 'seasonality_period': 12}     0.026293
#                                                                                                                                                      ...
# TWES {'beta': 0.5789473684210527, 'gamma': 1.0, 'alpha': 0.3157894736842105, 'AdaptationPeriod': 10, 'seasonality_period': 12}                     12.554580
# TWES {'beta': 0.8421052631578947, 'gamma': 0.7368421052631579, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}     12.564037
# TWES {'beta': 0.631578947368421, 'gamma': 0.7368421052631579, 'alpha': 0.3684210526315789, 'AdaptationPeriod': 10, 'seasonality_period': 12}       12.733667
# TWES {'beta': 0.9473684210526315, 'gamma': 0.894736842105263, 'alpha': 0.2631578947368421, 'AdaptationPeriod': 10, 'seasonality_period': 12}       12.790732
# TWES {'beta': 1.0, 'gamma': 0.47368421052631576, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}                   13.111023
# TWES {'beta': 0.8421052631578947, 'gamma': 0.9473684210526315, 'alpha': 0.42105263157894735, 'AdaptationPeriod': 10, 'seasonality_period': 12}     13.258756
# TWES {'beta': 1.0, 'gamma': 0.9473684210526315, 'alpha': 0.3684210526315789, 'AdaptationPeriod': 10, 'seasonality_period': 12}                     13.355999
# TWES {'beta': 0.894736842105263, 'gamma': 0.7368421052631579, 'alpha': 0.2631578947368421, 'AdaptationPeriod': 10, 'seasonality_period': 12}       13.402830
# TWES {'beta': 0.631578947368421, 'gamma': 0.9473684210526315, 'alpha': 0.3684210526315789, 'AdaptationPeriod': 10, 'seasonality_period': 12}       13.516306
# TWES {'beta': 0.9473684210526315, 'gamma': 0.3684210526315789, 'alpha': 0.2631578947368421, 'AdaptationPeriod': 10, 'seasonality_period': 12}      14.547686
# TWES {'beta': 0.8421052631578947, 'gamma': 0.9473684210526315, 'alpha': 0.10526315789473684, 'AdaptationPeriod': 10, 'seasonality_period': 12}     15.259071
# TWES {'beta': 0.894736842105263, 'gamma': 0.5263157894736842, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}      15.518196
# TWES {'beta': 0.7368421052631579, 'gamma': 0.894736842105263, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}      15.632496
# TWES {'beta': 0.9473684210526315, 'gamma': 0.9473684210526315, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}     16.194081
# TWES {'beta': 0.8421052631578947, 'gamma': 0.631578947368421, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}      16.419092
# TWES {'beta': 1.0, 'gamma': 1.0, 'alpha': 0.3157894736842105, 'AdaptationPeriod': 10, 'seasonality_period': 12}                                    18.669499
# TWES {'beta': 0.5789473684210527, 'gamma': 0.9473684210526315, 'alpha': 0.3684210526315789, 'AdaptationPeriod': 10, 'seasonality_period': 12}      18.831515
# TWES {'beta': 1.0, 'gamma': 0.42105263157894735, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}                   19.144515
# TWES {'beta': 0.894736842105263, 'gamma': 0.631578947368421, 'alpha': 0.2631578947368421, 'AdaptationPeriod': 10, 'seasonality_period': 12}        19.445783
# TWES {'beta': 1.0, 'gamma': 0.5263157894736842, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}                    20.181553
# TWES {'beta': 0.6842105263157894, 'gamma': 1.0, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}                    22.948306
# TWES {'beta': 0.5789473684210527, 'gamma': 1.0, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}                    22.989867
# TWES {'beta': 1.0, 'gamma': 0.7894736842105263, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}                    26.228267
# TWES {'beta': 0.631578947368421, 'gamma': 0.8421052631578947, 'alpha': 0.3157894736842105, 'AdaptationPeriod': 10, 'seasonality_period': 12}       27.784322
# TWES {'beta': 0.9473684210526315, 'gamma': 0.9473684210526315, 'alpha': 0.10526315789473684, 'AdaptationPeriod': 10, 'seasonality_period': 12}     35.932237
# TWES {'beta': 0.7368421052631579, 'gamma': 0.6842105263157894, 'alpha': 0.3157894736842105, 'AdaptationPeriod': 10, 'seasonality_period': 12}      41.667068
# TWES {'beta': 0.894736842105263, 'gamma': 1.0, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}                     44.541729
# TWES {'beta': 0.894736842105263, 'gamma': 0.7894736842105263, 'alpha': 0.3684210526315789, 'AdaptationPeriod': 10, 'seasonality_period': 12}       64.517398
# TWES {'beta': 0.9473684210526315, 'gamma': 0.7894736842105263, 'alpha': 0.3684210526315789, 'AdaptationPeriod': 10, 'seasonality_period': 12}      65.544414
# TWES {'beta': 0.7368421052631579, 'gamma': 1.0, 'alpha': 0.42105263157894735, 'AdaptationPeriod': 10, 'seasonality_period': 12}                    71.911845
# Length: 8000, dtype: float64

# %%
best_params = QualityStr[QualityStr.columns].mean().sort_values().index[0]
best_params
# Out:
# "TWES {'beta': 0.0, 'gamma': 1.0, 'alpha': 0.5789473684210527, 'AdaptationPeriod': 10, 'seasonality_period': 12}"

# %% [markdown]
# ## 2) draw the forecast with optimial value $\alpha $  (10%)

# %%
# example of code:
algName = QualityStr[QualityStr.columns].mean().sort_values().index[0]
plot_tsforecast(wage.loc['1998-09': '2017-01'], TWES_FRC_TS[algName].loc['1998-09': '2017-01'], ts_num=0, alg_title=algName)

# %% [markdown]
# ## 3) Calculate loss of the forecast of TS in [02.2015, 01.2017] (5%)

# %%
# example of code:
qualityMACAPE(wage.loc['2015-02':'2017-01'], TWES_FRC_TS[algName].loc['2015-02':'2017-01'])[0]
# Out:
# Real wage    0.018559
# dtype: float64

# %% [markdown]
# # 2. Non-additive model of ES (60%)
# You need to realize Winters model with linear trend and then use it for forecasting real TS <span style="color:blue; font-family:'New Times Roman'; font-size:14pt">monthly-wage.csv</span>.
#
# Forecast delay $h=1$ for all point in this task.

# %% [markdown]
# ## 1) Realize Winters Model with Linear trend (20%)

# %%
# Start with this code
###################### Winters Exponential Smoothing #########################
# x <array Tx1>- time series, 
# h <scalar> - forecasting delay
# Params <dict> - dictionary with 
#    alpha <scalar in [0,1]> - smoothing parameter of level
#    beta <scalar in [0,1]> - smoothing parameter of trend
#    gamma <scalar in [0,1]> - smoothing parameter of seasonality
def WintersLinearTrendExponentialSmoothing(x, h, Params):
    T = len(x)
    alpha = Params['alpha']
    beta = Params['beta']
    gamma = Params['gamma']
    
    p = Params['seasonality_period']
    
    FORECAST = [np.NaN]*(T+h) ## put foreast of the model here
    
    l = np.NaN # initialize ts level
    b = np.NaN # initialize ts trend
    s = [np.NaN] * p # initalize seasonality values (it must be vector of lenth p)\    l= np.NaN
    
    for cntr in range(T):
        if not math.isnan(x[cntr]):
            if math.isnan(l):
                l = x[cntr] # initialize
            
            if math.isnan(b):
                b = 0
 
            if math.isnan(s[cntr % p]):
                s[cntr % p] = x[cntr] # initialize
            else:
                s[cntr % p] = gamma * (x[cntr] / l) + (1 - gamma) * s[cntr % p] # recurrent smoothing of seasonality
            
            l_old = l
            l = alpha * (x[cntr] / s[cntr % p]) + (1 - alpha) * (l + b) # recurrent smoothing of level
            b = beta * (l - l_old) + (1 - beta) * b # recurrent smoothing of trend
            
        FORECAST[cntr+h] = (l + b * h) * s[((cntr + h) % p)]
        
    return FORECAST

# %% [markdown]
# ## 2) Find optimal params of the model (10%)
# (use data from 09.1998 to 01.2015). (Loss function should be the same as for Theil-Wage model)

# %%
# Put your code here
ALPHA = np.linspace(0.0, 1.0, 20)
BETA = np.linspace(0.0, 1.0, 20)
GAMMA = np.linspace(0.0, 1.0, 20)
WLTES_params_array = [{'beta':beta, 'gamma':gamma, 'alpha':alpha, 'AdaptationPeriod':10, 'seasonality_period':12} for gamma in GAMMA for beta in BETA for alpha in ALPHA]
WLTES_FRC_TS = build_forecast(h=1, ts=wage, algname = 'WintersLinearTrendExponentialSmoothing', algtitle='WLTES', params_array = WLTES_params_array, step='M')

# %%
QualityStr = pd.DataFrame(index = wage.columns, columns = WLTES_FRC_TS.keys())

ix = wage.loc['1998-09':'2015-01'].index
for param_cntr in sorted(QualityStr.columns):
    frc_wage = WLTES_FRC_TS[param_cntr]
    QualityStr[param_cntr],_ = qualityMACAPE(wage.loc[ix], frc_wage.loc[ix])

QualityStr[QualityStr.columns].mean().sort_values()
# Out:
# WLTES {'beta': 0.7368421052631579, 'gamma': 0.47368421052631576, 'alpha': 0.894736842105263, 'AdaptationPeriod': 10, 'seasonality_period': 12}         0.018326
# WLTES {'beta': 0.631578947368421, 'gamma': 0.47368421052631576, 'alpha': 0.9473684210526315, 'AdaptationPeriod': 10, 'seasonality_period': 12}         0.018332
# WLTES {'beta': 0.7894736842105263, 'gamma': 0.47368421052631576, 'alpha': 0.894736842105263, 'AdaptationPeriod': 10, 'seasonality_period': 12}         0.018332
# WLTES {'beta': 0.6842105263157894, 'gamma': 0.47368421052631576, 'alpha': 0.9473684210526315, 'AdaptationPeriod': 10, 'seasonality_period': 12}        0.018340
# WLTES {'beta': 0.8421052631578947, 'gamma': 0.47368421052631576, 'alpha': 0.894736842105263, 'AdaptationPeriod': 10, 'seasonality_period': 12}         0.018348
# WLTES {'beta': 0.8421052631578947, 'gamma': 0.47368421052631576, 'alpha': 0.8421052631578947, 'AdaptationPeriod': 10, 'seasonality_period': 12}        0.018354
# WLTES {'beta': 0.7894736842105263, 'gamma': 0.47368421052631576, 'alpha': 0.8421052631578947, 'AdaptationPeriod': 10, 'seasonality_period': 12}        0.018362
# WLTES {'beta': 0.894736842105263, 'gamma': 0.47368421052631576, 'alpha': 0.8421052631578947, 'AdaptationPeriod': 10, 'seasonality_period': 12}         0.018368
# WLTES {'beta': 0.7368421052631579, 'gamma': 0.47368421052631576, 'alpha': 0.9473684210526315, 'AdaptationPeriod': 10, 'seasonality_period': 12}        0.018369
# WLTES {'beta': 0.6842105263157894, 'gamma': 0.47368421052631576, 'alpha': 0.894736842105263, 'AdaptationPeriod': 10, 'seasonality_period': 12}         0.018371
# WLTES {'beta': 0.9473684210526315, 'gamma': 0.47368421052631576, 'alpha': 0.8421052631578947, 'AdaptationPeriod': 10, 'seasonality_period': 12}        0.018382
# WLTES {'beta': 0.894736842105263, 'gamma': 0.47368421052631576, 'alpha': 0.894736842105263, 'AdaptationPeriod': 10, 'seasonality_period': 12}          0.018387
# WLTES {'beta': 0.5789473684210527, 'gamma': 0.47368421052631576, 'alpha': 1.0, 'AdaptationPeriod': 10, 'seasonality_period': 12}                       0.018393
# WLTES {'beta': 0.5263157894736842, 'gamma': 0.47368421052631576, 'alpha': 1.0, 'AdaptationPeriod': 10, 'seasonality_period': 12}                       0.018402
# WLTES {'beta': 1.0, 'gamma': 0.47368421052631576, 'alpha': 0.8421052631578947, 'AdaptationPeriod': 10, 'seasonality_period': 12}                       0.018410
# WLTES {'beta': 0.631578947368421, 'gamma': 0.47368421052631576, 'alpha': 1.0, 'AdaptationPeriod': 10, 'seasonality_period': 12}                        0.018426
# WLTES {'beta': 0.7894736842105263, 'gamma': 0.47368421052631576, 'alpha': 0.9473684210526315, 'AdaptationPeriod': 10, 'seasonality_period': 12}        0.018431
# WLTES {'beta': 0.5789473684210527, 'gamma': 0.47368421052631576, 'alpha': 0.9473684210526315, 'AdaptationPeriod': 10, 'seasonality_period': 12}        0.018433
# WLTES {'beta': 0.7368421052631579, 'gamma': 0.5263157894736842, 'alpha': 1.0, 'AdaptationPeriod': 10, 'seasonality_period': 12}                        0.018442
# WLTES {'beta': 0.9473684210526315, 'gamma': 0.47368421052631576, 'alpha': 0.894736842105263, 'AdaptationPeriod': 10, 'seasonality_period': 12}         0.018448
# WLTES {'beta': 0.9473684210526315, 'gamma': 0.47368421052631576, 'alpha': 0.7894736842105263, 'AdaptationPeriod': 10, 'seasonality_period': 12}        0.018455
# WLTES {'beta': 1.0, 'gamma': 0.47368421052631576, 'alpha': 0.7894736842105263, 'AdaptationPeriod': 10, 'seasonality_period': 12}                       0.018467
# WLTES {'beta': 0.7368421052631579, 'gamma': 0.47368421052631576, 'alpha': 0.8421052631578947, 'AdaptationPeriod': 10, 'seasonality_period': 12}        0.018469
# WLTES {'beta': 0.894736842105263, 'gamma': 0.47368421052631576, 'alpha': 0.7894736842105263, 'AdaptationPeriod': 10, 'seasonality_period': 12}         0.018472
# WLTES {'beta': 0.8421052631578947, 'gamma': 0.5263157894736842, 'alpha': 0.9473684210526315, 'AdaptationPeriod': 10, 'seasonality_period': 12}         0.018479
# WLTES {'beta': 0.8421052631578947, 'gamma': 0.47368421052631576, 'alpha': 0.9473684210526315, 'AdaptationPeriod': 10, 'seasonality_period': 12}        0.018491
# WLTES {'beta': 0.6842105263157894, 'gamma': 0.47368421052631576, 'alpha': 1.0, 'AdaptationPeriod': 10, 'seasonality_period': 12}                       0.018496
# WLTES {'beta': 0.6842105263157894, 'gamma': 0.5263157894736842, 'alpha': 1.0, 'AdaptationPeriod': 10, 'seasonality_period': 12}                        0.018497
# WLTES {'beta': 0.631578947368421, 'gamma': 0.47368421052631576, 'alpha': 0.894736842105263, 'AdaptationPeriod': 10, 'seasonality_period': 12}          0.018501
# WLTES {'beta': 0.7894736842105263, 'gamma': 0.5263157894736842, 'alpha': 0.9473684210526315, 'AdaptationPeriod': 10, 'seasonality_period': 12}         0.018503
#                                                                                                                                                         ...
# WLTES {'beta': 0.5263157894736842, 'gamma': 0.8421052631578947, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}       35.680268
# WLTES {'beta': 0.6842105263157894, 'gamma': 0.5789473684210527, 'alpha': 0.05263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}       36.185533
# WLTES {'beta': 0.7368421052631579, 'gamma': 0.47368421052631576, 'alpha': 0.5263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}       36.257073
# WLTES {'beta': 0.7894736842105263, 'gamma': 0.5263157894736842, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}       38.342889
# WLTES {'beta': 0.3157894736842105, 'gamma': 0.42105263157894735, 'alpha': 0.3157894736842105, 'AdaptationPeriod': 10, 'seasonality_period': 12}       38.767775
# WLTES {'beta': 0.05263157894736842, 'gamma': 0.05263157894736842, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}     39.526319
# WLTES {'beta': 0.8421052631578947, 'gamma': 0.47368421052631576, 'alpha': 0.3684210526315789, 'AdaptationPeriod': 10, 'seasonality_period': 12}       40.463056
# WLTES {'beta': 0.5789473684210527, 'gamma': 0.894736842105263, 'alpha': 0.2631578947368421, 'AdaptationPeriod': 10, 'seasonality_period': 12}         40.799983
# WLTES {'beta': 0.9473684210526315, 'gamma': 0.8421052631578947, 'alpha': 0.2631578947368421, 'AdaptationPeriod': 10, 'seasonality_period': 12}        41.297639
# WLTES {'beta': 0.15789473684210525, 'gamma': 0.42105263157894735, 'alpha': 0.05263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}     41.965799
# WLTES {'beta': 1.0, 'gamma': 0.21052631578947367, 'alpha': 0.47368421052631576, 'AdaptationPeriod': 10, 'seasonality_period': 12}                     42.065786
# WLTES {'beta': 0.7368421052631579, 'gamma': 0.6842105263157894, 'alpha': 0.5263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}        46.051228
# WLTES {'beta': 0.894736842105263, 'gamma': 0.2631578947368421, 'alpha': 0.10526315789473684, 'AdaptationPeriod': 10, 'seasonality_period': 12}        50.743908
# WLTES {'beta': 0.7894736842105263, 'gamma': 0.5789473684210527, 'alpha': 0.3684210526315789, 'AdaptationPeriod': 10, 'seasonality_period': 12}        53.106771
# WLTES {'beta': 0.21052631578947367, 'gamma': 0.3684210526315789, 'alpha': 0.10526315789473684, 'AdaptationPeriod': 10, 'seasonality_period': 12}      55.423662
# WLTES {'beta': 0.47368421052631576, 'gamma': 0.3157894736842105, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}      56.565264
# WLTES {'beta': 0.10526315789473684, 'gamma': 0.3684210526315789, 'alpha': 0.631578947368421, 'AdaptationPeriod': 10, 'seasonality_period': 12}        66.376729
# WLTES {'beta': 0.6842105263157894, 'gamma': 0.7368421052631579, 'alpha': 0.2631578947368421, 'AdaptationPeriod': 10, 'seasonality_period': 12}        73.050748
# WLTES {'beta': 0.7368421052631579, 'gamma': 0.5263157894736842, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}       94.010702
# WLTES {'beta': 0.7894736842105263, 'gamma': 0.47368421052631576, 'alpha': 0.15789473684210525, 'AdaptationPeriod': 10, 'seasonality_period': 12}     103.280546
# WLTES {'beta': 0.631578947368421, 'gamma': 0.3684210526315789, 'alpha': 0.10526315789473684, 'AdaptationPeriod': 10, 'seasonality_period': 12}       112.638171
# WLTES {'beta': 0.7368421052631579, 'gamma': 0.5789473684210527, 'alpha': 0.2631578947368421, 'AdaptationPeriod': 10, 'seasonality_period': 12}       114.247334
# WLTES {'beta': 0.8421052631578947, 'gamma': 0.7368421052631579, 'alpha': 0.05263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}      148.736237
# WLTES {'beta': 0.3684210526315789, 'gamma': 0.7894736842105263, 'alpha': 0.3684210526315789, 'AdaptationPeriod': 10, 'seasonality_period': 12}       164.135928
# WLTES {'beta': 0.9473684210526315, 'gamma': 0.10526315789473684, 'alpha': 0.5263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}      167.537259
# WLTES {'beta': 0.8421052631578947, 'gamma': 0.3684210526315789, 'alpha': 0.42105263157894735, 'AdaptationPeriod': 10, 'seasonality_period': 12}      210.570960
# WLTES {'beta': 0.05263157894736842, 'gamma': 0.15789473684210525, 'alpha': 0.10526315789473684, 'AdaptationPeriod': 10, 'seasonality_period': 12}    220.231936
# WLTES {'beta': 0.7894736842105263, 'gamma': 0.7894736842105263, 'alpha': 0.05263157894736842, 'AdaptationPeriod': 10, 'seasonality_period': 12}      270.778162
# WLTES {'beta': 0.2631578947368421, 'gamma': 0.3157894736842105, 'alpha': 0.21052631578947367, 'AdaptationPeriod': 10, 'seasonality_period': 12}      312.799226
# WLTES {'beta': 0.894736842105263, 'gamma': 0.3684210526315789, 'alpha': 0.3684210526315789, 'AdaptationPeriod': 10, 'seasonality_period': 12}        363.692727
# Length: 8000, dtype: float64

# %%
best_params = QualityStr[QualityStr.columns].mean().sort_values().index[0]
best_params
# Out:
# "WLTES {'beta': 0.7368421052631579, 'gamma': 0.47368421052631576, 'alpha': 0.894736842105263, 'AdaptationPeriod': 10, 'seasonality_period': 12}"

# %% [markdown]
# ## 3) Draw forecast with optimal values of it's params (10%)
# (data from 09.1998 to 01.2017)

# %%
# Put your code here
algName_1 = QualityStr[QualityStr.columns].mean().sort_values().index[0]
plot_tsforecast(wage.loc['1998-09': '2017-01'], WLTES_FRC_TS[algName_1].loc['1998-09': '2017-01'], ts_num=0, alg_title=algName_1)

# %% [markdown]
# ## 4) Calculate accuracy of the forecast of TS in [02.2015, 01.2017] (10%)
# (Loss function should be the same as for Theil-Wage model).

# %%
# Put your code here
qualityMACAPE(wage.loc['2015-02':'2017-01'], WLTES_FRC_TS[algName_1].loc['2015-02':'2017-01'])[0]
# Out:
# Real wage    0.016001
# dtype: float64

# %% [markdown]
# ## 5) Compare Winters Model with linear thend and Theil-Wage model (10%)
# Which forecast is better (more accurate)?
# Is it true that multiplicative model is more appropriate then Theil-Wage Model to this time series?
# Hint: you should use for example Diebold-Mariano test (see here https://github.com/johntwk/Diebold-Mariano-Test) to make a conclusion.

# %%
# Put your code here
from dm_test import dm_test

# %%
algName
# Out:
# "TWES {'beta': 0.0, 'gamma': 1.0, 'alpha': 0.5789473684210527, 'AdaptationPeriod': 10, 'seasonality_period': 12}"

# %%
algName_1
# Out:
# "WLTES {'beta': 0.7368421052631579, 'gamma': 0.47368421052631576, 'alpha': 0.894736842105263, 'AdaptationPeriod': 10, 'seasonality_period': 12}"

# %%
dm_test(actual_lst=wage.loc['2015-02':'2017-01'].values.flatten(),
        pred1_lst=TWES_FRC_TS[algName].loc['2015-02':'2017-01'].values.flatten(),
        pred2_lst=WLTES_FRC_TS[algName_1].loc['2015-02':'2017-01'].values.flatten(),
       crit = 'MAPE')
# Out:
# dm_return(DM=1.239010750006238, p_value=0.2278371661850206)

# %%
from scipy.stats import norm
alpha = 0.05
abs(norm.ppf(alpha / 2))
# Out:
# 1.9599639845400545

# %% [markdown]
# Получили, что модуль значения DM не превосходит квантиля для  $\alpha$=0.05, значит, нулевая гипотеза о том, оба прогноза одинаково хороши, не отвергается. Но вообще, судя по ошибке, чуть лучше все-таки работает WLTES.
