# %%
import sys, math
import numpy as np
import matplotlib.pyplot as plt

# %%
import gym
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam, SGD
from keras.models import load_model
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import random

# %%
ENV_NAME = 'LunarLander-v2'

env = gym.make(ENV_NAME)
# To get repeatable results.
sd = 2
# np.random.seed(sd)
random.seed(sd)
env.seed(sd)
nb_actions = env.action_space.n

"""Keras model for a fully connected 4 layer NN"""
model = Sequential()
model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
model.add(Dense(40))
model.add(Activation('relu'))
model.add(Dense(40))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('linear'))
model.compile(loss='mean_squared_error',  optimizer=Adam(lr=0.002,
              decay=2.25e-05))
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 8)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                360
# _________________________________________________________________
# activation_1 (Activation)    (None, 40)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 40)                1640
# _________________________________________________________________
# activation_2 (Activation)    (None, 40)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 164
# _________________________________________________________________
# activation_3 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 2,164
# Trainable params: 2,164
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def forward_pass(state):
    input = np.empty([1, 1, 8])
    input[0][0] = state
    return model.predict(input)[0]

# %%
def get_best_action(state):
    """Returns the index of the action with the highest Q-value, i.e.
        argMax(Q(nxt_state, all_actions))
    """
    state_q_values = forward_pass(state)
    return np.argmax(state_q_values)

# %%
def get_targets(state, action, reward, next_state):
    """
    Returns a set of target Q-values for a particular <s, a, r, s'> tuple
    """
    current_state_q_values = forward_pass(state)
    next_state_q_values = forward_pass(next_state)
    max_q_next_state = np.max(next_state_q_values)
    targets = np.empty([1, nb_actions])

    for i in range(nb_actions):
        if i == action:
            targets[0][i] = reward + (gamma * max_q_next_state)
        else:
            targets[0][i] = current_state_q_values[i]
    return targets

# %%
def choose_action(state, epsilon):
    """
    Greedy-epsilon exploration. Chooses action with the highest Q(s,a) value.
    With probability epsilon chooses a random action.
    """
    r = np.random.uniform()
    if r < epsilon:
        action = np.floor(np.random.randint(nb_actions))
    else:
        action = get_best_action(state)
    return int(action)

# %%
class Memory(object):
    def __init__(self, memory_size=10000, experience_size=1):
        self.experiences = np.empty([0, experience_size], dtype=object)
        self.max_memory_size = memory_size

    def add_experience(self, experience):
        self.experiences = np.insert(self.experiences, 0,
                                     experience, axis=0)
        if len(self.experiences) > self.max_memory_size:
            self.experiences = np.delete(self.experiences,
                                         self.max_memory_size, axis=0)

    def sample_experiences(self, mini_batch_size):
        if(mini_batch_size > len(self.experiences)):
            rep_needed = True
        else:
            rep_needed = False
        s = self.experiences[np.random.choice(
                self.experiences.shape[0],
                mini_batch_size, replace=rep_needed)]
        return s

# %%
def pack_experience(state, action, reward, new_state):
    experience = np.empty([0])
    experience = np.append(experience, state)
    experience = np.append(experience, [action])
    experience = np.append(experience, [reward])
    experience = np.append(experience, new_state)
    return experience

# %%
def unpack_experience(experience):
    state = experience[0:8]
    action = experience[8]
    reward = experience[9]
    new_state = experience[10:18]
    return state, action, reward, new_state

# %%
def learn_from_replay_memories(memory, batch_size):
    """
    Take a uniformly distributed batch of experiences and set the corresponding
    targets. Then train the network sequentally on each individual
    (experience, target) pair.
    """
    sample_batch = memory.sample_experiences(batch_size)
    for e in sample_batch:
        state, action, reward, new_state = unpack_experience(e)
        targets = get_targets(state, action, reward, new_state)
        x = np.empty([1, 1, 8])
        x[0][0] = state
        model.train_on_batch(x, targets)

# %%
mini_batch_size = 5
replay_memory_size = 20
gamma = 0.1
epsilon = 0.1
max_steps_per_epoch = 1000
max_epochs = 5000

memory = Memory(replay_memory_size, 18)
total_reward = np.zeros(max_epochs)

# %%
for epoch in range(max_epochs):
    state = env.reset()
    current_step = 0
    epoch_done = False
    while current_step < max_steps_per_epoch and not epoch_done:
        # Choose an action using the greedy-epsilon policy
        action = choose_action(state, epsilon)
        new_state, reward, epoch_done, info = env.step(action)
        total_reward[epoch] = total_reward[epoch] + reward
        # Store the experience in memory buffer
        experience = pack_experience(state, action, reward, new_state)
        memory.add_experience(experience)

        current_step = current_step + 1
        state = new_state
        # Learn from past experiences
        learn_from_replay_memories(memory, mini_batch_size)

    if not epoch % 10 and epoch and gamma < 0.975:
        # Gradually increase gamma to improve the importance of future-rewards
        # as the NN learns and becomes more accurate
        gamma = gamma * 1.0125
        print("New gamma = {:.6}".format(gamma))

    print("Episode {} reward = {:.6}".format(epoch, total_reward[epoch]))
    if not epoch % 10 and epoch:
        print("---------------------------")
        print("Last 10 episode avg = {:.6}".format(np.average(total_reward[epoch-10:epoch])))
        print("---------------------------")

    if epoch and np.average(total_reward[epoch-100:epoch]) > 150:
        break
# Out:
# WARNING:tensorflow:Variable *= will be deprecated. Use variable.assign_mul if you want assignment to the variable value or 'x = x * y' if you want a new python Tensor object.
# Episode 0 reward = -87.1167
# Episode 1 reward = -259.304
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:1128: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Episode 2 reward = -515.312
# Episode 3 reward = -690.686
# Episode 4 reward = -581.656
# Episode 5 reward = -407.677
# Episode 6 reward = -182.731
# Episode 7 reward = -550.495
# Episode 8 reward = -684.048
# Episode 9 reward = -657.08
# New gamma = 0.10125
# Episode 10 reward = -673.2
# ---------------------------
# Last 10 episode avg = -461.611
# ---------------------------
# Episode 11 reward = -92.358
# Episode 12 reward = -183.011
# Episode 13 reward = -226.484
# Episode 14 reward = -248.508
# Episode 15 reward = -215.913
# Episode 16 reward = -78.1515
# Episode 17 reward = -203.97
# Episode 18 reward = -268.175
# Episode 19 reward = -262.515
# New gamma = 0.102516
# Episode 20 reward = -234.447
# ---------------------------
# Last 10 episode avg = -245.228
# ---------------------------
# Episode 21 reward = -81.9291
# Episode 22 reward = -817.279
# Episode 23 reward = -333.162
# Episode 24 reward = 179.31
# Episode 25 reward = -132.286
# Episode 26 reward = 241.509
# Episode 27 reward = -538.863
# Episode 28 reward = -899.65
# Episode 29 reward = -294.642
# New gamma = 0.103797
# Episode 30 reward = -216.885
# ---------------------------
# Last 10 episode avg = -291.144
# ---------------------------
# Episode 31 reward = -141.733
# Episode 32 reward = -162.545
# Episode 33 reward = -112.134
# Episode 34 reward = -306.811
# Episode 35 reward = -56.5104
# Episode 36 reward = -82.2936
# Episode 37 reward = -173.857
# Episode 38 reward = -59.6926
# Episode 39 reward = -81.0444
# New gamma = 0.105095
# Episode 40 reward = -239.985
# ---------------------------
# Last 10 episode avg = -139.351
# ---------------------------
# Episode 41 reward = -196.375
# Episode 42 reward = -327.058
# Episode 43 reward = -228.048
# Episode 44 reward = -185.28
# Episode 45 reward = -341.822
# Episode 46 reward = -241.479
# Episode 47 reward = -454.558
# Episode 48 reward = -189.891
# Episode 49 reward = -202.427
# New gamma = 0.106408
# Episode 50 reward = 2.73663
# ---------------------------
# Last 10 episode avg = -260.692
# ---------------------------
# Episode 51 reward = -541.53
# Episode 52 reward = -216.063
# Episode 53 reward = -220.805
# Episode 54 reward = -207.559
# Episode 55 reward = -34.9442
# Episode 56 reward = -77.2122
# Episode 57 reward = -295.005
# Episode 58 reward = -217.145
# Episode 59 reward = -170.083
# New gamma = 0.107738
# Episode 60 reward = -235.928
# ---------------------------
# Last 10 episode avg = -197.761
# ---------------------------
# Episode 61 reward = -141.5
# Episode 62 reward = -99.8789
# Episode 63 reward = -153.309
# Episode 64 reward = -166.459
# Episode 65 reward = -150.275
# Episode 66 reward = -101.58
# Episode 67 reward = -144.439
# Episode 68 reward = -305.534
# Episode 69 reward = -416.577
# New gamma = 0.109085
# Episode 70 reward = -82.4575
# ---------------------------
# Last 10 episode avg = -191.548
# ---------------------------
# Episode 71 reward = -384.399
# Episode 72 reward = -423.206
# Episode 73 reward = -350.192
# Episode 74 reward = -21.7712
# Episode 75 reward = -19.324
# Episode 76 reward = 27.6399
# Episode 77 reward = 260.118
# Episode 78 reward = -304.456
# Episode 79 reward = -754.388
# New gamma = 0.110449
# Episode 80 reward = -147.968
# ---------------------------
# Last 10 episode avg = -205.244
# ---------------------------
# Episode 81 reward = -397.955
# Episode 82 reward = -8.43691
# Episode 83 reward = -526.294
# Episode 84 reward = -231.741
# Episode 85 reward = -257.693
# Episode 86 reward = -409.93
# Episode 87 reward = -360.633
# Episode 88 reward = -18.3373
# Episode 89 reward = -30.6481
# New gamma = 0.111829
# Episode 90 reward = -213.191
# ---------------------------
# Last 10 episode avg = -238.964
# ---------------------------
# Episode 91 reward = 4.02297
# Episode 92 reward = -42.5089
# Episode 93 reward = -164.424
# Episode 94 reward = -15.3164
# Episode 95 reward = -127.993
# Episode 96 reward = -242.464
# Episode 97 reward = -50.1912
# Episode 98 reward = -25.8714
# Episode 99 reward = -68.4795
# New gamma = 0.113227
# Episode 100 reward = -68.0384
# ---------------------------
# Last 10 episode avg = -94.6417
# ---------------------------
# Episode 101 reward = -95.473
# Episode 102 reward = -104.497
# Episode 103 reward = -91.4419
# Episode 104 reward = -219.969
# Episode 105 reward = -366.351
# Episode 106 reward = -196.155
# Episode 107 reward = -242.31
# Episode 108 reward = -362.213
# Episode 109 reward = -137.012
# New gamma = 0.114642
# Episode 110 reward = -62.849
# ---------------------------
# Last 10 episode avg = -188.346
# ---------------------------
# Episode 111 reward = -76.5386
# Episode 112 reward = -16.605
# Episode 113 reward = -213.636
# Episode 114 reward = 197.316
# Episode 115 reward = -223.518
# Episode 116 reward = -368.573
# Episode 117 reward = -242.248
# Episode 118 reward = -183.185
# Episode 119 reward = -304.532
# New gamma = 0.116075
# Episode 120 reward = -189.878
# ---------------------------
# Last 10 episode avg = -149.437
# ---------------------------
# Episode 121 reward = -42.1866
# Episode 122 reward = -19.5132
# Episode 123 reward = -104.457
# Episode 124 reward = -71.9797
# Episode 125 reward = -69.0689
# Episode 126 reward = -251.119
# Episode 127 reward = -248.082
# Episode 128 reward = -172.015
# Episode 129 reward = -205.826
# New gamma = 0.117526
# Episode 130 reward = -233.183
# ---------------------------
# Last 10 episode avg = -137.412
# ---------------------------
# Episode 131 reward = -64.8476
# Episode 132 reward = -224.651
# Episode 133 reward = -185.434
# Episode 134 reward = -117.452
# Episode 135 reward = -542.821
# Episode 136 reward = -107.527
# Episode 137 reward = -253.652
# Episode 138 reward = -253.761
# Episode 139 reward = -477.172
# New gamma = 0.118995
# Episode 140 reward = -584.155
# ---------------------------
# Last 10 episode avg = -246.05
# ---------------------------
# Episode 141 reward = -746.988
# Episode 142 reward = -623.338
# Episode 143 reward = -718.57
# Episode 144 reward = -344.67
# Episode 145 reward = -54.7986
# Episode 146 reward = -178.072
# Episode 147 reward = -471.595
# Episode 148 reward = -30.1528
# Episode 149 reward = -168.813
# New gamma = 0.120483
# Episode 150 reward = -398.437
# ---------------------------
# Last 10 episode avg = -392.115
# ---------------------------
# Episode 151 reward = -93.4258
# Episode 152 reward = -54.3621
# Episode 153 reward = -245.468
# Episode 154 reward = -161.756
# Episode 155 reward = -110.38
# Episode 156 reward = -83.6119
# Episode 157 reward = -43.9906
# Episode 158 reward = 0.807425
# Episode 159 reward = -78.7224
# New gamma = 0.121989
# Episode 160 reward = -193.012
# ---------------------------
# Last 10 episode avg = -126.935
# ---------------------------
# Episode 161 reward = -161.471
# Episode 162 reward = -9.68275
# Episode 163 reward = -328.405
# Episode 164 reward = -188.709
# Episode 165 reward = -543.378
# Episode 166 reward = -456.256
# Episode 167 reward = -55.8195
# Episode 168 reward = -71.4275
# Episode 169 reward = -145.278
# New gamma = 0.123514
# Episode 170 reward = -50.2561
# ---------------------------
# Last 10 episode avg = -215.344
# ---------------------------
# Episode 171 reward = -172.663
# Episode 172 reward = 66.2992
# Episode 173 reward = -392.379
# Episode 174 reward = -148.099
# Episode 175 reward = -48.8654
# Episode 176 reward = -382.168
# Episode 177 reward = -237.959
# Episode 178 reward = -90.8446
# Episode 179 reward = -195.612
# New gamma = 0.125058
# Episode 180 reward = -152.444
# ---------------------------
# Last 10 episode avg = -165.255
# ---------------------------
# Episode 181 reward = -287.499
# Episode 182 reward = -245.28
# Episode 183 reward = -167.406
# Episode 184 reward = -80.8184
# Episode 185 reward = -44.0779
# Episode 186 reward = -88.6642
# Episode 187 reward = -13.5523
# Episode 188 reward = -242.874
# Episode 189 reward = 22.2944
# New gamma = 0.126621
# Episode 190 reward = -90.1092
# ---------------------------
# Last 10 episode avg = -130.032
# ---------------------------
# Episode 191 reward = -402.521
# Episode 192 reward = -360.979
# Episode 193 reward = -409.904
# Episode 194 reward = -91.511
# Episode 195 reward = -85.1537
# Episode 196 reward = -61.1538
# Episode 197 reward = -175.766
# Episode 198 reward = -96.0465
# Episode 199 reward = -157.071
# New gamma = 0.128204
# Episode 200 reward = -39.3965
# ---------------------------
# Last 10 episode avg = -193.021
# ---------------------------
# Episode 201 reward = -213.063
# Episode 202 reward = -366.508
# Episode 203 reward = -166.653
# Episode 204 reward = -214.977
# Episode 205 reward = 7.68081
# Episode 206 reward = -200.393
# Episode 207 reward = -48.3945
# Episode 208 reward = -48.2567
# Episode 209 reward = -174.322
# New gamma = 0.129806
# Episode 210 reward = -42.0982
# ---------------------------
# Last 10 episode avg = -146.428
# ---------------------------
# Episode 211 reward = -165.968
# Episode 212 reward = -204.55
# Episode 213 reward = -203.694
# Episode 214 reward = -72.0148
# Episode 215 reward = -547.557
# Episode 216 reward = -272.969
# Episode 217 reward = -247.031
# Episode 218 reward = -4.30828
# Episode 219 reward = -42.392
# New gamma = 0.131429
# Episode 220 reward = -182.34
# ---------------------------
# Last 10 episode avg = -180.258
# ---------------------------
# Episode 221 reward = -161.278
# Episode 222 reward = -18.5035
# Episode 223 reward = -62.5831
# Episode 224 reward = -53.1985
# Episode 225 reward = -226.04
# Episode 226 reward = -21.6795
# Episode 227 reward = -52.4841
# Episode 228 reward = -103.047
# Episode 229 reward = -134.431
# New gamma = 0.133072
# Episode 230 reward = -58.5678
# ---------------------------
# Last 10 episode avg = -101.558
# ---------------------------
# Episode 231 reward = -240.462
# Episode 232 reward = -107.533
# Episode 233 reward = -274.787
# Episode 234 reward = -76.8845
# Episode 235 reward = -226.161
# Episode 236 reward = -318.912
# Episode 237 reward = -234.438
# Episode 238 reward = -351.188
# Episode 239 reward = -177.231
# New gamma = 0.134735
# Episode 240 reward = -376.642
# ---------------------------
# Last 10 episode avg = -206.616
# ---------------------------
# Episode 241 reward = -404.868
# Episode 242 reward = -371.47
# Episode 243 reward = -37.8327
# Episode 244 reward = -105.206
# Episode 245 reward = -334.033
# Episode 246 reward = -76.374
# Episode 247 reward = -194.76
# Episode 248 reward = -256.379
# Episode 249 reward = -45.1829
# New gamma = 0.136419
# Episode 250 reward = -137.666
# ---------------------------
# Last 10 episode avg = -220.275
# ---------------------------
# Episode 251 reward = -140.294
# Episode 252 reward = -171.389
# Episode 253 reward = -117.951
# Episode 254 reward = -70.124
# Episode 255 reward = -126.778
# Episode 256 reward = -274.633
# Episode 257 reward = -85.4377
# Episode 258 reward = -58.7698
# Episode 259 reward = -370.097
# New gamma = 0.138125
# Episode 260 reward = -371.263
# ---------------------------
# Last 10 episode avg = -155.314
# ---------------------------
# Episode 261 reward = -391.402
# Episode 262 reward = -83.8746
# Episode 263 reward = -230.163
# Episode 264 reward = -169.471
# Episode 265 reward = -166.492
# Episode 266 reward = -179.498
# Episode 267 reward = -341.017
# Episode 268 reward = -83.7202
# Episode 269 reward = -227.46
# New gamma = 0.139851
# Episode 270 reward = -66.8015
# ---------------------------
# Last 10 episode avg = -224.436
# ---------------------------
# Episode 271 reward = -95.3026
# Episode 272 reward = -201.653
# Episode 273 reward = -395.692
# Episode 274 reward = -195.581
# Episode 275 reward = -120.55
# Episode 276 reward = -765.554
# Episode 277 reward = -639.9
# Episode 278 reward = -297.806
# Episode 279 reward = -55.8477
# New gamma = 0.141599
# Episode 280 reward = -36.1327
# ---------------------------
# Last 10 episode avg = -283.469
# ---------------------------
# Episode 281 reward = -241.962
# Episode 282 reward = 44.4996
# Episode 283 reward = -47.2395
# Episode 284 reward = -72.1503
# Episode 285 reward = -287.674
# Episode 286 reward = -56.1028
# Episode 287 reward = -241.234
# Episode 288 reward = 18.5034
# Episode 289 reward = -80.3464
# New gamma = 0.143369
# Episode 290 reward = -212.361
# ---------------------------
# Last 10 episode avg = -99.9839
# ---------------------------
# Episode 291 reward = -289.552
# Episode 292 reward = 11.9329
# Episode 293 reward = -54.6202
# Episode 294 reward = -176.905
# Episode 295 reward = -57.6109
# Episode 296 reward = -203.216
# Episode 297 reward = 15.3166
# Episode 298 reward = 0.745896
# Episode 299 reward = -122.608
# New gamma = 0.145161
# Episode 300 reward = -187.046
# ---------------------------
# Last 10 episode avg = -108.888
# ---------------------------
# Episode 301 reward = -220.354
# Episode 302 reward = 11.3828
# Episode 303 reward = -39.7608
# Episode 304 reward = -772.321
# Episode 305 reward = -176.194
# Episode 306 reward = -48.5037
# Episode 307 reward = -240.805
# Episode 308 reward = -40.693
# Episode 309 reward = -76.7996
# New gamma = 0.146976
# Episode 310 reward = -139.783
# ---------------------------
# Last 10 episode avg = -179.11
# ---------------------------
# Episode 311 reward = -213.37
# Episode 312 reward = -167.067
# Episode 313 reward = -180.38
# Episode 314 reward = -228.031
# Episode 315 reward = -242.984
# Episode 316 reward = 4.67324
# Episode 317 reward = -69.0032
# Episode 318 reward = -175.7
# Episode 319 reward = 38.3678
# New gamma = 0.148813
# Episode 320 reward = -94.7469
# ---------------------------
# Last 10 episode avg = -137.328
# ---------------------------
# Episode 321 reward = -345.991
# Episode 322 reward = -147.918
# Episode 323 reward = -224.469
# Episode 324 reward = -391.848
# Episode 325 reward = -160.818
# Episode 326 reward = -68.2109
# Episode 327 reward = -19.0809
# Episode 328 reward = -121.594
# Episode 329 reward = 233.573
# New gamma = 0.150673
# Episode 330 reward = -128.585
# ---------------------------
# Last 10 episode avg = -134.11
# ---------------------------
# Episode 331 reward = -108.42
# Episode 332 reward = -232.435
# Episode 333 reward = -209.989
# Episode 334 reward = -263.898
# Episode 335 reward = -172.083
# Episode 336 reward = -225.355
# Episode 337 reward = -94.1267
# Episode 338 reward = -135.427
# Episode 339 reward = -359.371
# New gamma = 0.152557
# Episode 340 reward = -63.8683
# ---------------------------
# Last 10 episode avg = -192.969
# ---------------------------
# Episode 341 reward = -201.167
# Episode 342 reward = -11.8314
# Episode 343 reward = -207.686
# Episode 344 reward = -23.4261
# Episode 345 reward = -157.196
# Episode 346 reward = -107.503
# Episode 347 reward = 4.43899
# Episode 348 reward = -49.4238
# Episode 349 reward = -236.276
# New gamma = 0.154464
# Episode 350 reward = -154.761
# ---------------------------
# Last 10 episode avg = -105.394
# ---------------------------
# Episode 351 reward = -94.0874
# Episode 352 reward = -211.451
# Episode 353 reward = -26.2474
# Episode 354 reward = -52.1576
# Episode 355 reward = -454.539
# Episode 356 reward = -229.781
# Episode 357 reward = -218.864
# Episode 358 reward = -90.8106
# Episode 359 reward = -112.0
# New gamma = 0.156394
# Episode 360 reward = -33.8869
# ---------------------------
# Last 10 episode avg = -164.47
# ---------------------------
# Episode 361 reward = -82.7038
# Episode 362 reward = -209.517
# Episode 363 reward = -60.2242
# Episode 364 reward = -168.09
# Episode 365 reward = -53.6737
# Episode 366 reward = -104.983
# Episode 367 reward = -175.712
# Episode 368 reward = -393.679
# Episode 369 reward = -234.831
# New gamma = 0.158349
# Episode 370 reward = -300.288
# ---------------------------
# Last 10 episode avg = -151.73
# ---------------------------
# Episode 371 reward = -60.4763
# Episode 372 reward = -132.149
# Episode 373 reward = -130.035
# Episode 374 reward = -107.564
# Episode 375 reward = -71.4828
# Episode 376 reward = -374.943
# Episode 377 reward = -94.6768
# Episode 378 reward = -240.819
# Episode 379 reward = -82.4572
# New gamma = 0.160329
# Episode 380 reward = -214.156
# ---------------------------
# Last 10 episode avg = -159.489
# ---------------------------
# Episode 381 reward = -39.1528
# Episode 382 reward = -224.573
# Episode 383 reward = -37.8835
# Episode 384 reward = -180.182
# Episode 385 reward = -55.3945
# Episode 386 reward = -67.213
# Episode 387 reward = -195.5
# Episode 388 reward = -202.844
# Episode 389 reward = -50.7738
# New gamma = 0.162333
# Episode 390 reward = -145.072
# ---------------------------
# Last 10 episode avg = -126.767
# ---------------------------
# Episode 391 reward = -155.906
# Episode 392 reward = 285.919
# Episode 393 reward = -221.433
# Episode 394 reward = -83.8476
# Episode 395 reward = -286.808
# Episode 396 reward = -16.897
# Episode 397 reward = -177.027
# Episode 398 reward = -224.228
# Episode 399 reward = -191.226
# New gamma = 0.164362
# Episode 400 reward = 274.163
# ---------------------------
# Last 10 episode avg = -121.652
# ---------------------------
# Episode 401 reward = -24.054
# Episode 402 reward = -161.347
# Episode 403 reward = -126.488
# Episode 404 reward = -264.786
# Episode 405 reward = -369.074
# Episode 406 reward = -218.74
# Episode 407 reward = -167.815
# Episode 408 reward = -354.523
# Episode 409 reward = -237.219
# New gamma = 0.166416
# Episode 410 reward = -187.427
# ---------------------------
# Last 10 episode avg = -164.989
# ---------------------------
# Episode 411 reward = -238.606
# Episode 412 reward = -162.714
# Episode 413 reward = -161.36
# Episode 414 reward = -200.648
# Episode 415 reward = -113.385
# Episode 416 reward = -222.208
# Episode 417 reward = -104.607
# Episode 418 reward = -225.174
# Episode 419 reward = -310.237
# New gamma = 0.168497
# Episode 420 reward = -135.339
# ---------------------------
# Last 10 episode avg = -192.637
# ---------------------------
# Episode 421 reward = -216.32
# Episode 422 reward = -54.4658
# Episode 423 reward = -79.0616
# Episode 424 reward = -35.3838
# Episode 425 reward = -201.822
# Episode 426 reward = -224.464
# Episode 427 reward = -139.63
# Episode 428 reward = -110.488
# Episode 429 reward = -246.513
# New gamma = 0.170603
# Episode 430 reward = 201.695
# ---------------------------
# Last 10 episode avg = -144.349
# ---------------------------
# Episode 431 reward = -218.815
# Episode 432 reward = -198.132
# Episode 433 reward = -32.6443
# Episode 434 reward = -23.4292
# Episode 435 reward = -282.909
# Episode 436 reward = -122.414
# Episode 437 reward = -163.868
# Episode 438 reward = -230.31
# Episode 439 reward = -240.082
# New gamma = 0.172735
# Episode 440 reward = 182.008
# ---------------------------
# Last 10 episode avg = -131.091
# ---------------------------
# Episode 441 reward = -222.075
# Episode 442 reward = -9.47597
# Episode 443 reward = 31.8996
# Episode 444 reward = -279.564
# Episode 445 reward = -214.608
# Episode 446 reward = -50.9579
# Episode 447 reward = -12.3501
# Episode 448 reward = -166.326
# Episode 449 reward = -249.105
# New gamma = 0.174895
# Episode 450 reward = -195.588
# ---------------------------
# Last 10 episode avg = -99.0553
# ---------------------------
# Episode 451 reward = 21.1129
# Episode 452 reward = -300.823
# Episode 453 reward = -13.2367
# Episode 454 reward = -55.2946
# Episode 455 reward = -102.922
# Episode 456 reward = -155.908
# Episode 457 reward = -210.632
# Episode 458 reward = -119.928
# Episode 459 reward = -285.111
# New gamma = 0.177081
# Episode 460 reward = -218.935
# ---------------------------
# Last 10 episode avg = -141.833
# ---------------------------
# Episode 461 reward = -251.199
# Episode 462 reward = -222.626
# Episode 463 reward = -46.7316
# Episode 464 reward = -247.765
# Episode 465 reward = -164.666
# Episode 466 reward = -69.6157
# Episode 467 reward = 4.90279
# Episode 468 reward = -191.237
# Episode 469 reward = -53.7364
# New gamma = 0.179294
# Episode 470 reward = -58.005
# ---------------------------
# Last 10 episode avg = -146.161
# ---------------------------
# Episode 471 reward = 1.04507
# Episode 472 reward = -58.3893
# Episode 473 reward = -61.368
# Episode 474 reward = -218.355
# Episode 475 reward = -40.6968
# Episode 476 reward = -92.3051
# Episode 477 reward = -236.919
# Episode 478 reward = -226.012
# Episode 479 reward = -195.266
# New gamma = 0.181535
# Episode 480 reward = -217.667
# ---------------------------
# Last 10 episode avg = -118.627
# ---------------------------
# Episode 481 reward = -53.419
# Episode 482 reward = -19.4359
# Episode 483 reward = -57.1376
# Episode 484 reward = -62.7439
# Episode 485 reward = -117.008
# Episode 486 reward = -32.764
# Episode 487 reward = -22.1306
# Episode 488 reward = -219.269
# Episode 489 reward = -110.119
# New gamma = 0.183805
# Episode 490 reward = 210.28
# ---------------------------
# Last 10 episode avg = -91.1695
# ---------------------------
# Episode 491 reward = -219.573
# Episode 492 reward = -288.076
# Episode 493 reward = -286.375
# Episode 494 reward = -97.5947
# Episode 495 reward = -183.845
# Episode 496 reward = 12.6549
# Episode 497 reward = -64.4339
# Episode 498 reward = -242.346
# Episode 499 reward = -186.693
# New gamma = 0.186102
# Episode 500 reward = -22.8853
# ---------------------------
# Last 10 episode avg = -134.6
# ---------------------------
# Episode 501 reward = -277.769
# Episode 502 reward = -144.412
# Episode 503 reward = 15.0618
# Episode 504 reward = -201.777
# Episode 505 reward = 28.9156
# Episode 506 reward = -11.6371
# Episode 507 reward = -227.892
# Episode 508 reward = 4.64459
# Episode 509 reward = -57.3882
# New gamma = 0.188429
# Episode 510 reward = 19.09
# ---------------------------
# Last 10 episode avg = -89.5138
# ---------------------------
# Episode 511 reward = -26.8539
# Episode 512 reward = -83.9548
# Episode 513 reward = -55.5921
# Episode 514 reward = -164.803
# Episode 515 reward = 294.403
# Episode 516 reward = 8.71611
# Episode 517 reward = -46.2339
# Episode 518 reward = -15.1253
# Episode 519 reward = -216.735
# New gamma = 0.190784
# Episode 520 reward = 9.82253
# ---------------------------
# Last 10 episode avg = -28.7088
# ---------------------------
# Episode 521 reward = -59.2884
# Episode 522 reward = -229.773
# Episode 523 reward = -268.073
# Episode 524 reward = -155.307
# Episode 525 reward = -61.9927
# Episode 526 reward = -97.7842
# Episode 527 reward = -48.9147
# Episode 528 reward = -182.649
# Episode 529 reward = 178.784
# New gamma = 0.193169
# Episode 530 reward = -229.904
# ---------------------------
# Last 10 episode avg = -91.5174
# ---------------------------
# Episode 531 reward = -139.856
# Episode 532 reward = -232.242
# Episode 533 reward = -161.95
# Episode 534 reward = -230.97
# Episode 535 reward = 22.7127
# Episode 536 reward = -209.443
# Episode 537 reward = -27.1361
# Episode 538 reward = -200.175
# Episode 539 reward = -100.368
# New gamma = 0.195583
# Episode 540 reward = -46.3818
# ---------------------------
# Last 10 episode avg = -150.933
# ---------------------------
# Episode 541 reward = -169.692
# Episode 542 reward = 169.103
# Episode 543 reward = -256.657
# Episode 544 reward = -221.866
# Episode 545 reward = -8.61973
# Episode 546 reward = 258.839
# Episode 547 reward = -22.1774
# Episode 548 reward = -137.257
# Episode 549 reward = -15.7617
# New gamma = 0.198028
# Episode 550 reward = -261.514
# ---------------------------
# Last 10 episode avg = -45.047
# ---------------------------
# Episode 551 reward = -23.7417
# Episode 552 reward = -83.2109
# Episode 553 reward = -196.505
# Episode 554 reward = -202.981
# Episode 555 reward = -82.1819
# Episode 556 reward = -56.7605
# Episode 557 reward = -199.944
# Episode 558 reward = -35.4752
# Episode 559 reward = -189.675
# New gamma = 0.200503
# Episode 560 reward = -9.44776
# ---------------------------
# Last 10 episode avg = -133.199
# ---------------------------
# Episode 561 reward = -15.9526
# Episode 562 reward = -225.963
# Episode 563 reward = -71.2796
# Episode 564 reward = 148.292
# Episode 565 reward = -56.0693
# Episode 566 reward = -139.389
# Episode 567 reward = -81.913
# Episode 568 reward = -218.003
# Episode 569 reward = -196.919
# New gamma = 0.20301
# Episode 570 reward = -272.343
# ---------------------------
# Last 10 episode avg = -86.6644
# ---------------------------
# Episode 571 reward = -75.4302
# Episode 572 reward = -209.869
# Episode 573 reward = -188.389
# Episode 574 reward = -176.628
# Episode 575 reward = 267.11
# Episode 576 reward = -37.641
# Episode 577 reward = -207.645
# Episode 578 reward = -53.4184
# Episode 579 reward = 35.3445
# New gamma = 0.205547
# Episode 580 reward = -109.218
# ---------------------------
# Last 10 episode avg = -91.8909
# ---------------------------
# Episode 581 reward = -323.952
# Episode 582 reward = -16.6851
# Episode 583 reward = 122.63
# Episode 584 reward = -77.5402
# Episode 585 reward = -245.254
# Episode 586 reward = -185.559
# Episode 587 reward = -45.68
# Episode 588 reward = -26.8104
# Episode 589 reward = -256.423
# New gamma = 0.208117
# Episode 590 reward = -248.169
# ---------------------------
# Last 10 episode avg = -116.449
# ---------------------------
# Episode 591 reward = -141.227
# Episode 592 reward = 177.89
# Episode 593 reward = -180.973
# Episode 594 reward = -243.506
# Episode 595 reward = -144.538
# Episode 596 reward = -19.1262
# Episode 597 reward = -101.075
# Episode 598 reward = -199.209
# Episode 599 reward = 246.324
# New gamma = 0.210718
# Episode 600 reward = -224.27
# ---------------------------
# Last 10 episode avg = -85.361
# ---------------------------
# Episode 601 reward = -225.756
# Episode 602 reward = -60.6563
# Episode 603 reward = -83.7278
# Episode 604 reward = 1.46318
# Episode 605 reward = 237.547
# Episode 606 reward = -258.623
# Episode 607 reward = -98.2911
# Episode 608 reward = -199.519
# Episode 609 reward = -191.215
# New gamma = 0.213352
# Episode 610 reward = 36.3984
# ---------------------------
# Last 10 episode avg = -110.305
# ---------------------------
# Episode 611 reward = -83.6635
# Episode 612 reward = 255.842
# Episode 613 reward = 13.8086
# Episode 614 reward = -53.5123
# Episode 615 reward = -44.1289
# Episode 616 reward = -165.58
# Episode 617 reward = -256.461
# Episode 618 reward = -105.93
# Episode 619 reward = -209.678
# New gamma = 0.216019
# Episode 620 reward = -50.5561
# ---------------------------
# Last 10 episode avg = -61.2904
# ---------------------------
# Episode 621 reward = 20.6792
# Episode 622 reward = -74.2691
# Episode 623 reward = -52.4044
# Episode 624 reward = -67.6056
# Episode 625 reward = 38.8567
# Episode 626 reward = -37.7654
# Episode 627 reward = -243.843
# Episode 628 reward = 284.353
# Episode 629 reward = -42.9922
# New gamma = 0.218719
# Episode 630 reward = 50.2625
# ---------------------------
# Last 10 episode avg = -22.5547
# ---------------------------
# Episode 631 reward = -155.513
# Episode 632 reward = 281.457
# Episode 633 reward = 250.215
# Episode 634 reward = -30.5526
# Episode 635 reward = -36.0449
# Episode 636 reward = 38.4182
# Episode 637 reward = -45.8414
# Episode 638 reward = -50.5901
# Episode 639 reward = -115.05
# New gamma = 0.221453
# Episode 640 reward = -38.8675
# ---------------------------
# Last 10 episode avg = 18.6761
# ---------------------------
# Episode 641 reward = -180.962
# Episode 642 reward = -32.4215
# Episode 643 reward = -15.9925
# Episode 644 reward = -28.2866
# Episode 645 reward = -228.566
# Episode 646 reward = -226.753
# Episode 647 reward = -200.477
# Episode 648 reward = -200.652
# Episode 649 reward = 244.177
# New gamma = 0.224221
# Episode 650 reward = 42.3932
# ---------------------------
# Last 10 episode avg = -90.8801
# ---------------------------
# Episode 651 reward = -12.8304
# Episode 652 reward = 269.252
# Episode 653 reward = -34.6127
# Episode 654 reward = -228.699
# Episode 655 reward = -109.184
# Episode 656 reward = -96.6238
# Episode 657 reward = -18.125
# Episode 658 reward = -50.413
# Episode 659 reward = 36.4954
# New gamma = 0.227024
# Episode 660 reward = -236.956
# ---------------------------
# Last 10 episode avg = -20.2348
# ---------------------------
# Episode 661 reward = -55.7348
# Episode 662 reward = 3.56766
# Episode 663 reward = -298.111
# Episode 664 reward = -174.626
# Episode 665 reward = -241.125
# Episode 666 reward = -179.342
# Episode 667 reward = 4.22934
# Episode 668 reward = -219.834
# Episode 669 reward = -193.161
# New gamma = 0.229862
# Episode 670 reward = -171.763
# ---------------------------
# Last 10 episode avg = -159.109
# ---------------------------
# Episode 671 reward = -30.0255
# Episode 672 reward = -101.968
# Episode 673 reward = -252.988
# Episode 674 reward = 210.567
# Episode 675 reward = -236.709
# Episode 676 reward = 233.811
# Episode 677 reward = -24.1226
# Episode 678 reward = -28.9379
# Episode 679 reward = -221.617
# New gamma = 0.232735
# Episode 680 reward = -17.1787
# ---------------------------
# Last 10 episode avg = -62.3753
# ---------------------------
# Episode 681 reward = -56.525
# Episode 682 reward = -221.479
# Episode 683 reward = -53.0467
# Episode 684 reward = -131.893
# Episode 685 reward = -260.121
# Episode 686 reward = -194.986
# Episode 687 reward = -202.195
# Episode 688 reward = -35.941
# Episode 689 reward = -9.93949
# New gamma = 0.235644
# Episode 690 reward = -35.2208
# ---------------------------
# Last 10 episode avg = -118.33
# ---------------------------
# Episode 691 reward = -289.579
# Episode 692 reward = -23.6865
# Episode 693 reward = -8.01761
# Episode 694 reward = -12.5759
# Episode 695 reward = -194.101
# Episode 696 reward = -47.9106
# Episode 697 reward = -49.2421
# Episode 698 reward = -107.757
# Episode 699 reward = -171.135
# New gamma = 0.23859
# Episode 700 reward = -21.1937
# ---------------------------
# Last 10 episode avg = -93.9226
# ---------------------------
# Episode 701 reward = -32.2814
# Episode 702 reward = -157.58
# Episode 703 reward = -69.5206
# Episode 704 reward = -51.7428
# Episode 705 reward = -112.697
# Episode 706 reward = -203.27
# Episode 707 reward = -35.3388
# Episode 708 reward = -143.835
# Episode 709 reward = -262.854
# New gamma = 0.241572
# Episode 710 reward = -77.4188
# ---------------------------
# Last 10 episode avg = -109.031
# ---------------------------
# Episode 711 reward = 19.062
# Episode 712 reward = -125.713
# Episode 713 reward = -176.747
# Episode 714 reward = -82.6549
# Episode 715 reward = -238.267
# Episode 716 reward = -210.613
# Episode 717 reward = -27.6286
# Episode 718 reward = -183.637
# Episode 719 reward = -31.5475
# New gamma = 0.244592
# Episode 720 reward = -173.306
# ---------------------------
# Last 10 episode avg = -113.516
# ---------------------------
# Episode 721 reward = -191.004
# Episode 722 reward = -254.867
# Episode 723 reward = -64.2955
# Episode 724 reward = -219.234
# Episode 725 reward = -53.3953
# Episode 726 reward = -179.446
# Episode 727 reward = -239.278
# Episode 728 reward = 214.055
# Episode 729 reward = -252.185
# New gamma = 0.247649
# Episode 730 reward = -8.46022
# ---------------------------
# Last 10 episode avg = -141.296
# ---------------------------
# Episode 731 reward = -236.734
# Episode 732 reward = -45.4306
# Episode 733 reward = -201.182
# Episode 734 reward = -233.657
# Episode 735 reward = -42.2536
# Episode 736 reward = -181.452
# Episode 737 reward = -208.321
# Episode 738 reward = -164.995
# Episode 739 reward = -246.202
# New gamma = 0.250745
# Episode 740 reward = -44.4587
# ---------------------------
# Last 10 episode avg = -156.869
# ---------------------------
# Episode 741 reward = -185.832
# Episode 742 reward = -242.25
# Episode 743 reward = -41.3127
# Episode 744 reward = -16.2305
# Episode 745 reward = -13.3662
# Episode 746 reward = -70.3436
# Episode 747 reward = -260.853
# Episode 748 reward = -16.587
# Episode 749 reward = -76.7914
# New gamma = 0.253879
# Episode 750 reward = -24.9328
# ---------------------------
# Last 10 episode avg = -96.8026
# ---------------------------
# Episode 751 reward = -45.0615
# Episode 752 reward = 232.089
# Episode 753 reward = 179.277
# Episode 754 reward = -233.086
# Episode 755 reward = -42.9913
# Episode 756 reward = -59.531
# Episode 757 reward = -33.8989
# Episode 758 reward = 186.51
# Episode 759 reward = 54.8375
# New gamma = 0.257053
# Episode 760 reward = -16.3411
# ---------------------------
# Last 10 episode avg = 21.3212
# ---------------------------
# Episode 761 reward = -223.886
# Episode 762 reward = -216.072
# Episode 763 reward = -196.564
# Episode 764 reward = 14.8744
# Episode 765 reward = -218.667
# Episode 766 reward = -33.7643
# Episode 767 reward = -150.255
# Episode 768 reward = -231.024
# Episode 769 reward = -191.761
# New gamma = 0.260266
# Episode 770 reward = -260.972
# ---------------------------
# Last 10 episode avg = -146.346
# ---------------------------
# Episode 771 reward = -27.4788
# Episode 772 reward = 28.2449
# Episode 773 reward = -225.093
# Episode 774 reward = -48.48
# Episode 775 reward = -137.981
# Episode 776 reward = -96.2289
# Episode 777 reward = -175.773
# Episode 778 reward = -163.281
# Episode 779 reward = 28.7768
# New gamma = 0.263519
# Episode 780 reward = -242.622
# ---------------------------
# Last 10 episode avg = -107.827
# ---------------------------
# Episode 781 reward = -183.117
# Episode 782 reward = 67.3932
# Episode 783 reward = -149.611
# Episode 784 reward = -178.35
# Episode 785 reward = -32.9985
# Episode 786 reward = -54.4389
# Episode 787 reward = -42.6719
# Episode 788 reward = -39.9553
# Episode 789 reward = 1.91877
# New gamma = 0.266813
# Episode 790 reward = 86.2805
# ---------------------------
# Last 10 episode avg = -85.4452
# ---------------------------
# Episode 791 reward = -257.134
# Episode 792 reward = -18.7335
# Episode 793 reward = 229.501
# Episode 794 reward = -20.3344
# Episode 795 reward = -138.636
# Episode 796 reward = -11.1579
# Episode 797 reward = 71.0319
# Episode 798 reward = -207.823
# Episode 799 reward = -66.3286
# New gamma = 0.270148
# Episode 800 reward = -20.9987
# ---------------------------
# Last 10 episode avg = -33.3334
# ---------------------------
# Episode 801 reward = -203.096
# Episode 802 reward = -50.7851
# Episode 803 reward = 202.295
# Episode 804 reward = 64.8823
# Episode 805 reward = -146.117
# Episode 806 reward = -20.7719
# Episode 807 reward = -179.109
# Episode 808 reward = -18.4693
# Episode 809 reward = -162.727
# New gamma = 0.273525
# Episode 810 reward = -51.508
# ---------------------------
# Last 10 episode avg = -53.4897
# ---------------------------
# Episode 811 reward = -216.136
# Episode 812 reward = -215.794
# Episode 813 reward = -186.794
# Episode 814 reward = -191.369
# Episode 815 reward = -169.859
# Episode 816 reward = 203.433
# Episode 817 reward = 4.57713
# Episode 818 reward = -128.506
# Episode 819 reward = -32.5788
# New gamma = 0.276944
# Episode 820 reward = -191.735
# ---------------------------
# Last 10 episode avg = -98.4534
# ---------------------------
# Episode 821 reward = -69.5301
# Episode 822 reward = -218.988
# Episode 823 reward = -33.0987
# Episode 824 reward = -24.3555
# Episode 825 reward = -161.621
# Episode 826 reward = -14.8873
# Episode 827 reward = -46.2461
# Episode 828 reward = -19.1432
# Episode 829 reward = -44.724
# New gamma = 0.280406
# Episode 830 reward = -35.6218
# ---------------------------
# Last 10 episode avg = -82.4329
# ---------------------------
# Episode 831 reward = -217.335
# Episode 832 reward = -15.0944
# Episode 833 reward = 35.5056
# Episode 834 reward = -210.192
# Episode 835 reward = 1.06403
# Episode 836 reward = -236.92
# Episode 837 reward = -74.4326
# Episode 838 reward = -29.6055
# Episode 839 reward = 177.316
# New gamma = 0.283911
# Episode 840 reward = -273.292
# ---------------------------
# Last 10 episode avg = -60.5316
# ---------------------------
# Episode 841 reward = -173.971
# Episode 842 reward = -49.1973
# Episode 843 reward = -199.078
# Episode 844 reward = -40.1946
# Episode 845 reward = -242.509
# Episode 846 reward = -180.803
# Episode 847 reward = -29.3952
# Episode 848 reward = -238.432
# Episode 849 reward = 198.264
# New gamma = 0.28746
# Episode 850 reward = -88.1632
# ---------------------------
# Last 10 episode avg = -122.861
# ---------------------------
# Episode 851 reward = -160.085
# Episode 852 reward = -241.063
# Episode 853 reward = -167.423
# Episode 854 reward = -234.373
# Episode 855 reward = -75.0437
# Episode 856 reward = -9.95256
# Episode 857 reward = -36.4975
# Episode 858 reward = -173.481
# Episode 859 reward = -264.666
# New gamma = 0.291053
# Episode 860 reward = -17.8159
# ---------------------------
# Last 10 episode avg = -145.075
# ---------------------------
# Episode 861 reward = -158.982
# Episode 862 reward = 3.77848
# Episode 863 reward = -228.163
# Episode 864 reward = -28.3329
# Episode 865 reward = -34.0081
# Episode 866 reward = -16.4564
# Episode 867 reward = -187.988
# Episode 868 reward = -197.413
# Episode 869 reward = -84.9875
# New gamma = 0.294692
# Episode 870 reward = -235.249
# ---------------------------
# Last 10 episode avg = -95.0368
# ---------------------------
# Episode 871 reward = 212.281
# Episode 872 reward = 1.31261
# Episode 873 reward = 32.9278
# Episode 874 reward = -31.8423
# Episode 875 reward = -149.602
# Episode 876 reward = -37.9208
# Episode 877 reward = -53.5654
# Episode 878 reward = 67.3933
# Episode 879 reward = -61.6796
# New gamma = 0.298375
# Episode 880 reward = -49.9277
# ---------------------------
# Last 10 episode avg = -25.5944
# ---------------------------
# Episode 881 reward = -188.908
# Episode 882 reward = -178.604
# Episode 883 reward = 14.0965
# Episode 884 reward = -216.277
# Episode 885 reward = 0.840481
# Episode 886 reward = -34.3354
# Episode 887 reward = -123.462
# Episode 888 reward = -172.333
# Episode 889 reward = -0.517588
# New gamma = 0.302105
# Episode 890 reward = -113.372
# ---------------------------
# Last 10 episode avg = -94.9428
# ---------------------------
# Episode 891 reward = -208.697
# Episode 892 reward = -46.0982
# Episode 893 reward = -152.595
# Episode 894 reward = 4.42079
# Episode 895 reward = -0.943615
# Episode 896 reward = -213.72
# Episode 897 reward = -8.95207
# Episode 898 reward = -68.6122
# Episode 899 reward = 57.5258
# New gamma = 0.305881
# Episode 900 reward = -125.75
# ---------------------------
# Last 10 episode avg = -75.1045
# ---------------------------
# Episode 901 reward = -157.433
# Episode 902 reward = -58.5058
# Episode 903 reward = -45.3065
# Episode 904 reward = -15.3241
# Episode 905 reward = -235.647
# Episode 906 reward = -72.4673
# Episode 907 reward = -63.167
# Episode 908 reward = -74.6432
# Episode 909 reward = -183.355
# New gamma = 0.309705
# Episode 910 reward = -40.643
# ---------------------------
# Last 10 episode avg = -103.16
# ---------------------------
# Episode 911 reward = -189.321
# Episode 912 reward = -228.635
# Episode 913 reward = -170.869
# Episode 914 reward = 43.1037
# Episode 915 reward = -58.9432
# Episode 916 reward = -237.943
# Episode 917 reward = 44.478
# Episode 918 reward = -86.9655
# Episode 919 reward = -4.41593
# New gamma = 0.313576
# Episode 920 reward = 47.067
# ---------------------------
# Last 10 episode avg = -93.0154
# ---------------------------
# Episode 921 reward = -60.601
# Episode 922 reward = 0.0155899
# Episode 923 reward = -52.603
# Episode 924 reward = -38.7869
# Episode 925 reward = -97.9144
# Episode 926 reward = -258.003
# Episode 927 reward = -70.1872
# Episode 928 reward = -288.119
# Episode 929 reward = 248.007
# New gamma = 0.317496
# Episode 930 reward = -207.268
# ---------------------------
# Last 10 episode avg = -57.1124
# ---------------------------
# Episode 931 reward = -19.2119
# Episode 932 reward = -2.80871
# Episode 933 reward = -182.84
# Episode 934 reward = -72.7277
# Episode 935 reward = -217.896
# Episode 936 reward = -271.064
# Episode 937 reward = 232.971
# Episode 938 reward = -61.5858
# Episode 939 reward = -242.455
# New gamma = 0.321464
# Episode 940 reward = -34.0773
# ---------------------------
# Last 10 episode avg = -104.489
# ---------------------------
# Episode 941 reward = 231.835
# Episode 942 reward = -31.5187
# Episode 943 reward = -18.2133
# Episode 944 reward = -246.936
# Episode 945 reward = 9.98831
# Episode 946 reward = -203.085
# Episode 947 reward = -4.51801
# Episode 948 reward = -188.655
# Episode 949 reward = -152.778
# New gamma = 0.325483
# Episode 950 reward = -15.4351
# ---------------------------
# Last 10 episode avg = -63.7957
# ---------------------------
# Episode 951 reward = -196.383
# Episode 952 reward = -104.311
# Episode 953 reward = -28.8905
# Episode 954 reward = -208.827
# Episode 955 reward = -25.7185
# Episode 956 reward = -234.572
# Episode 957 reward = -43.539
# Episode 958 reward = -201.94
# Episode 959 reward = -237.113
# New gamma = 0.329551
# Episode 960 reward = 33.1569
# ---------------------------
# Last 10 episode avg = -129.673
# ---------------------------
# Episode 961 reward = -26.8521
# Episode 962 reward = -101.906
# Episode 963 reward = 270.507
# Episode 964 reward = -180.931
# Episode 965 reward = -236.813
# Episode 966 reward = 11.558
# Episode 967 reward = -180.019
# Episode 968 reward = -42.056
# Episode 969 reward = 6.33304
# New gamma = 0.333671
# Episode 970 reward = -10.3688
# ---------------------------
# Last 10 episode avg = -44.7022
# ---------------------------
# Episode 971 reward = 54.2235
# Episode 972 reward = -249.376
# Episode 973 reward = -37.3331
# Episode 974 reward = -36.0346
# Episode 975 reward = -124.839
# Episode 976 reward = 31.0142
# Episode 977 reward = -116.906
# Episode 978 reward = -210.796
# Episode 979 reward = -228.141
# New gamma = 0.337842
# Episode 980 reward = 71.6845
# ---------------------------
# Last 10 episode avg = -92.8556
# ---------------------------
# Episode 981 reward = -98.563
# Episode 982 reward = -100.907
# Episode 983 reward = -4.95816
# Episode 984 reward = -179.325
# Episode 985 reward = 231.375
# Episode 986 reward = -269.593
# Episode 987 reward = -167.698
# Episode 988 reward = 255.915
# Episode 989 reward = -63.798
# New gamma = 0.342065
# Episode 990 reward = -28.1818
# ---------------------------
# Last 10 episode avg = -32.5867
# ---------------------------
# Episode 991 reward = 80.1356
# Episode 992 reward = -198.97
# Episode 993 reward = -213.831
# Episode 994 reward = 9.26416
# Episode 995 reward = -3.07564
# Episode 996 reward = -81.0703
# Episode 997 reward = -54.2279
# Episode 998 reward = -17.861
# Episode 999 reward = 214.118
# New gamma = 0.34634
# Episode 1000 reward = -103.633
# ---------------------------
# Last 10 episode avg = -29.3699
# ---------------------------
# Episode 1001 reward = -16.7896
# Episode 1002 reward = -17.8595
# Episode 1003 reward = -191.934
# Episode 1004 reward = -28.0118
# Episode 1005 reward = -127.275
# Episode 1006 reward = 210.509
# Episode 1007 reward = 14.001
# Episode 1008 reward = 193.697
# Episode 1009 reward = -24.9147
# New gamma = 0.35067
# Episode 1010 reward = 6.79054
# ---------------------------
# Last 10 episode avg = -9.22096
# ---------------------------
# Episode 1011 reward = -18.8498
# Episode 1012 reward = -42.783
# Episode 1013 reward = -46.027
# Episode 1014 reward = -86.1151
# Episode 1015 reward = -169.513
# Episode 1016 reward = -187.751
# Episode 1017 reward = -38.5719
# Episode 1018 reward = -136.515
# Episode 1019 reward = -215.72
# New gamma = 0.355053
# Episode 1020 reward = -13.3713
# ---------------------------
# Last 10 episode avg = -93.5056
# ---------------------------
# Episode 1021 reward = -195.992
# Episode 1022 reward = -26.7019
# Episode 1023 reward = -18.0482
# Episode 1024 reward = -1.39376
# Episode 1025 reward = -196.263
# Episode 1026 reward = -24.1675
# Episode 1027 reward = -168.376
# Episode 1028 reward = -173.434
# Episode 1029 reward = -3.26268
# New gamma = 0.359491
# Episode 1030 reward = -228.094
# ---------------------------
# Last 10 episode avg = -82.101
# ---------------------------
# Episode 1031 reward = -20.855
# Episode 1032 reward = -177.361
# Episode 1033 reward = 33.7254
# Episode 1034 reward = -111.275
# Episode 1035 reward = -61.7884
# Episode 1036 reward = -80.0837
# Episode 1037 reward = -16.4217
# Episode 1038 reward = -214.964
# Episode 1039 reward = -11.2576
# New gamma = 0.363985
# Episode 1040 reward = -113.313
# ---------------------------
# Last 10 episode avg = -88.8374
# ---------------------------
# Episode 1041 reward = -318.51
# Episode 1042 reward = -58.796
# Episode 1043 reward = -192.13
# Episode 1044 reward = 0.812566
# Episode 1045 reward = -257.737
# Episode 1046 reward = 12.2977
# Episode 1047 reward = -164.978
# Episode 1048 reward = -251.293
# Episode 1049 reward = 16.9914
# New gamma = 0.368535
# Episode 1050 reward = -39.2196
# ---------------------------
# Last 10 episode avg = -132.666
# ---------------------------
# Episode 1051 reward = -125.945
# Episode 1052 reward = -53.7652
# Episode 1053 reward = -196.96
# Episode 1054 reward = -27.7324
# Episode 1055 reward = 5.67974
# Episode 1056 reward = -242.824
# Episode 1057 reward = -58.4748
# Episode 1058 reward = -196.813
# Episode 1059 reward = -211.919
# New gamma = 0.373141
# Episode 1060 reward = -16.8032
# ---------------------------
# Last 10 episode avg = -114.797
# ---------------------------
# Episode 1061 reward = -226.757
# Episode 1062 reward = -209.452
# Episode 1063 reward = -226.453
# Episode 1064 reward = -173.941
# Episode 1065 reward = -237.976
# Episode 1066 reward = -217.369
# Episode 1067 reward = -11.9622
# Episode 1068 reward = 3.02191
# Episode 1069 reward = -42.7489
# New gamma = 0.377806
# Episode 1070 reward = -49.9067
# ---------------------------
# Last 10 episode avg = -136.044
# ---------------------------
# Episode 1071 reward = -37.2677
# Episode 1072 reward = -162.23
# Episode 1073 reward = -99.1333
# Episode 1074 reward = -23.6329
# Episode 1075 reward = -191.111
# Episode 1076 reward = -14.6741
# Episode 1077 reward = -162.178
# Episode 1078 reward = 8.53721
# Episode 1079 reward = -16.1885
# New gamma = 0.382528
# Episode 1080 reward = -188.63
# ---------------------------
# Last 10 episode avg = -74.7785
# ---------------------------
# Episode 1081 reward = -228.255
# Episode 1082 reward = -213.207
# Episode 1083 reward = 12.9368
# Episode 1084 reward = -49.1255
# Episode 1085 reward = -181.861
# Episode 1086 reward = -172.913
# Episode 1087 reward = -57.619
# Episode 1088 reward = 224.209
# Episode 1089 reward = -11.2811
# New gamma = 0.38731
# Episode 1090 reward = -159.55
# ---------------------------
# Last 10 episode avg = -86.5746
# ---------------------------
# Episode 1091 reward = -3.71362
# Episode 1092 reward = -27.8772
# Episode 1093 reward = -57.0226
# Episode 1094 reward = -169.0
# Episode 1095 reward = -45.1671
# Episode 1096 reward = -254.45
# Episode 1097 reward = 266.8
# Episode 1098 reward = -189.203
# Episode 1099 reward = 13.1378
# New gamma = 0.392151
# Episode 1100 reward = 7.84554
# ---------------------------
# Last 10 episode avg = -62.6047
# ---------------------------
# Episode 1101 reward = -41.6681
# Episode 1102 reward = -175.304
# Episode 1103 reward = -210.801
# Episode 1104 reward = -28.3924
# Episode 1105 reward = 178.186
# Episode 1106 reward = -66.1124
# Episode 1107 reward = 58.7365
# Episode 1108 reward = -168.068
# Episode 1109 reward = -175.561
# New gamma = 0.397053
# Episode 1110 reward = -205.534
# ---------------------------
# Last 10 episode avg = -62.1138
# ---------------------------
# Episode 1111 reward = -158.706
# Episode 1112 reward = -186.123
# Episode 1113 reward = -32.9121
# Episode 1114 reward = -33.9489
# Episode 1115 reward = -81.4159
# Episode 1116 reward = -208.376
# Episode 1117 reward = -185.121
# Episode 1118 reward = 259.778
# Episode 1119 reward = -139.541
# New gamma = 0.402016
# Episode 1120 reward = -24.9762
# ---------------------------
# Last 10 episode avg = -97.1902
# ---------------------------
# Episode 1121 reward = -0.894759
# Episode 1122 reward = -171.213
# Episode 1123 reward = -38.3723
# Episode 1124 reward = -193.92
# Episode 1125 reward = -1.22024
# Episode 1126 reward = -197.644
# Episode 1127 reward = -19.4401
# Episode 1128 reward = 2.71657
# Episode 1129 reward = -177.339
# New gamma = 0.407041
# Episode 1130 reward = -42.8833
# ---------------------------
# Last 10 episode avg = -82.2303
# ---------------------------
# Episode 1131 reward = -46.8369
# Episode 1132 reward = -78.1158
# Episode 1133 reward = -18.1095
# Episode 1134 reward = -55.1602
# Episode 1135 reward = -23.7943
# Episode 1136 reward = -58.0128
# Episode 1137 reward = 1.89293
# Episode 1138 reward = -25.3644
# Episode 1139 reward = -49.549
# New gamma = 0.412129
# Episode 1140 reward = -260.935
# ---------------------------
# Last 10 episode avg = -39.5933
# ---------------------------
# Episode 1141 reward = -181.895
# Episode 1142 reward = -174.548
# Episode 1143 reward = -61.9962
# Episode 1144 reward = -198.248
# Episode 1145 reward = 63.1043
# Episode 1146 reward = -193.838
# Episode 1147 reward = -59.6129
# Episode 1148 reward = 279.721
# Episode 1149 reward = -45.2681
# New gamma = 0.417281
# Episode 1150 reward = -165.384
# ---------------------------
# Last 10 episode avg = -83.3515
# ---------------------------
# Episode 1151 reward = -203.795
# Episode 1152 reward = -207.08
# Episode 1153 reward = 25.7576
# Episode 1154 reward = -27.3087
# Episode 1155 reward = 40.6509
# Episode 1156 reward = -28.9016
# Episode 1157 reward = -207.3
# Episode 1158 reward = -143.328
# Episode 1159 reward = 12.4971
# New gamma = 0.422497
# Episode 1160 reward = -42.055
# ---------------------------
# Last 10 episode avg = -90.4192
# ---------------------------
# Episode 1161 reward = -120.119
# Episode 1162 reward = -236.638
# Episode 1163 reward = -207.789
# Episode 1164 reward = -266.301
# Episode 1165 reward = -210.544
# Episode 1166 reward = -37.6818
# Episode 1167 reward = -216.199
# Episode 1168 reward = -210.056
# Episode 1169 reward = -207.442
# New gamma = 0.427778
# Episode 1170 reward = -80.8388
# ---------------------------
# Last 10 episode avg = -175.482
# ...
# ---------------------------
# Last 10 episode avg = 145.912
# ---------------------------
# Episode 2921 reward = 199.837
# Episode 2922 reward = -9.959
# Episode 2923 reward = 203.969
# Episode 2924 reward = 249.855
# Episode 2925 reward = 26.1508
# Episode 2926 reward = 3.94791
# Episode 2927 reward = -72.45
# Episode 2928 reward = -73.7284
# Episode 2929 reward = 191.809
# Episode 2930 reward = 146.668
# ---------------------------
# Last 10 episode avg = 87.8423
# ---------------------------
# Episode 2931 reward = 186.453
# Episode 2932 reward = 213.753
# Episode 2933 reward = -28.1473
# Episode 2934 reward = 184.408
# Episode 2935 reward = 187.754
# Episode 2936 reward = 171.958
# Episode 2937 reward = -67.139
# Episode 2938 reward = -33.5104
# Episode 2939 reward = 205.903
# Episode 2940 reward = 178.497
# ---------------------------
# Last 10 episode avg = 116.81
# ---------------------------
# Episode 2941 reward = 240.452
# Episode 2942 reward = -181.195
# Episode 2943 reward = -63.7319
# Episode 2944 reward = 162.227
# Episode 2945 reward = 11.7231
# Episode 2946 reward = 194.364
# Episode 2947 reward = -38.3804
# Episode 2948 reward = 152.197
# Episode 2949 reward = 151.27
# Episode 2950 reward = 181.138
# ---------------------------
# Last 10 episode avg = 80.7423
# ---------------------------
# Episode 2951 reward = 213.973
# Episode 2952 reward = 164.024
# Episode 2953 reward = 279.767
# Episode 2954 reward = 121.947
# Episode 2955 reward = 293.196
# Episode 2956 reward = 183.148
# Episode 2957 reward = 184.761
# Episode 2958 reward = 60.0392
# Episode 2959 reward = 186.821
# Episode 2960 reward = -63.8984
# ---------------------------
# Last 10 episode avg = 186.881
# ---------------------------
# Episode 2961 reward = 162.626
# Episode 2962 reward = 154.838
# Episode 2963 reward = 138.57
# Episode 2964 reward = 63.1334
# Episode 2965 reward = 179.972
# Episode 2966 reward = 150.755
# Episode 2967 reward = 185.92
# Episode 2968 reward = 26.4685
# Episode 2969 reward = 248.893
# Episode 2970 reward = 175.584
# ---------------------------
# Last 10 episode avg = 124.728
# ---------------------------
# Episode 2971 reward = -64.1836
# Episode 2972 reward = -2.9645
# Episode 2973 reward = 83.5773
# Episode 2974 reward = 220.255
# Episode 2975 reward = -30.8721
# Episode 2976 reward = 69.8943
# Episode 2977 reward = -175.201
# Episode 2978 reward = 103.809
# Episode 2979 reward = 252.14
# Episode 2980 reward = 155.624
# ---------------------------
# Last 10 episode avg = 63.2037
# ---------------------------
# Episode 2981 reward = 232.668
# Episode 2982 reward = 189.172
# Episode 2983 reward = 108.004
# Episode 2984 reward = 217.578
# Episode 2985 reward = 229.272
# Episode 2986 reward = 198.666
# Episode 2987 reward = 268.553
# Episode 2988 reward = -15.9545
# Episode 2989 reward = 200.021
# Episode 2990 reward = 36.6527
# ---------------------------
# Last 10 episode avg = 178.36
# ---------------------------
# Episode 2991 reward = 295.65
# Episode 2992 reward = 17.9058
# Episode 2993 reward = 302.351
# Episode 2994 reward = -28.8607
# Episode 2995 reward = -65.6719
# Episode 2996 reward = -17.8024
# Episode 2997 reward = 187.249
# Episode 2998 reward = -3.7592
# Episode 2999 reward = 199.861
# Episode 3000 reward = -42.0204
# ---------------------------
# Last 10 episode avg = 92.3575
# ---------------------------
# Episode 3001 reward = -90.2032
# Episode 3002 reward = -21.4341
# Episode 3003 reward = -67.836
# Episode 3004 reward = -1.38987
# Episode 3005 reward = -49.2615
# Episode 3006 reward = 23.4489
# Episode 3007 reward = 34.5827
# Episode 3008 reward = 207.198
# Episode 3009 reward = -29.9598
# Episode 3010 reward = 222.498
# ---------------------------
# Last 10 episode avg = -3.68758
# ---------------------------
# Episode 3011 reward = -23.868
# Episode 3012 reward = 220.629
# Episode 3013 reward = 217.781
# Episode 3014 reward = 142.665
# Episode 3015 reward = 181.072
# Episode 3016 reward = 68.0597
# Episode 3017 reward = 164.846
# Episode 3018 reward = 48.1056
# Episode 3019 reward = -79.6502
# Episode 3020 reward = -76.8107
# ---------------------------
# Last 10 episode avg = 116.214
# ---------------------------
# Episode 3021 reward = 180.677
# Episode 3022 reward = 156.976
# Episode 3023 reward = -83.2818
# Episode 3024 reward = 180.748
# Episode 3025 reward = 195.791
# Episode 3026 reward = 200.783
# Episode 3027 reward = 195.387
# Episode 3028 reward = 163.967
# Episode 3029 reward = 222.909
# Episode 3030 reward = 112.653
# ---------------------------
# Last 10 episode avg = 133.714
# ---------------------------
# Episode 3031 reward = -57.6949
# Episode 3032 reward = -33.7701
# Episode 3033 reward = -180.384
# Episode 3034 reward = -95.1199
# Episode 3035 reward = 209.666
# Episode 3036 reward = 229.26
# Episode 3037 reward = 59.1865
# Episode 3038 reward = 229.721
# Episode 3039 reward = 170.462
# Episode 3040 reward = 29.2792
# ---------------------------
# Last 10 episode avg = 64.3979
# ---------------------------
# Episode 3041 reward = -101.479
# Episode 3042 reward = -185.701
# Episode 3043 reward = 139.794
# Episode 3044 reward = -8.64066
# Episode 3045 reward = 211.463
# Episode 3046 reward = 197.736
# Episode 3047 reward = 176.551
# Episode 3048 reward = 75.0805
# Episode 3049 reward = 179.398
# Episode 3050 reward = 199.413
# ---------------------------
# Last 10 episode avg = 71.3481
# ---------------------------
# Episode 3051 reward = 203.165
# Episode 3052 reward = 17.9288
# Episode 3053 reward = 127.752
# Episode 3054 reward = 104.58
# Episode 3055 reward = 234.517
# Episode 3056 reward = 163.244
# Episode 3057 reward = 156.21
# Episode 3058 reward = 249.894
# Episode 3059 reward = 190.848
# Episode 3060 reward = 212.221
# ---------------------------
# Last 10 episode avg = 164.755
# ---------------------------
# Episode 3061 reward = 215.52
# Episode 3062 reward = 227.049
# Episode 3063 reward = 225.297
# Episode 3064 reward = 39.7671
# Episode 3065 reward = 205.153
# Episode 3066 reward = 297.419
# Episode 3067 reward = 202.663
# Episode 3068 reward = 87.3225
# Episode 3069 reward = 96.0837
# Episode 3070 reward = 194.257
# ---------------------------
# Last 10 episode avg = 180.849
# ---------------------------
# Episode 3071 reward = -0.944619
# Episode 3072 reward = -8.83196
# Episode 3073 reward = 230.187
# Episode 3074 reward = 63.9843
# Episode 3075 reward = -106.171
# Episode 3076 reward = 3.01338
# Episode 3077 reward = 23.632
# Episode 3078 reward = 200.908
# Episode 3079 reward = 263.18
# Episode 3080 reward = 271.22
# ---------------------------
# Last 10 episode avg = 86.3214
# ---------------------------
# Episode 3081 reward = 217.647
# Episode 3082 reward = 234.496
# Episode 3083 reward = 234.844
# Episode 3084 reward = -9.56911
# Episode 3085 reward = -135.571
# Episode 3086 reward = 164.3
# Episode 3087 reward = -59.6715
# Episode 3088 reward = 292.061
# Episode 3089 reward = -31.9063
# Episode 3090 reward = 205.04
# ---------------------------
# Last 10 episode avg = 117.785
# ---------------------------
# Episode 3091 reward = 216.586
# Episode 3092 reward = -51.736
# Episode 3093 reward = 229.057
# Episode 3094 reward = 242.237
# Episode 3095 reward = 155.093
# Episode 3096 reward = 82.8755
# Episode 3097 reward = 138.109
# Episode 3098 reward = -88.6487
# Episode 3099 reward = -19.0449
# Episode 3100 reward = 138.701
# ---------------------------
# Last 10 episode avg = 110.957
# ---------------------------
# Episode 3101 reward = 196.274
# Episode 3102 reward = 256.846
# Episode 3103 reward = 189.283
# Episode 3104 reward = 166.555
# Episode 3105 reward = 165.699
# Episode 3106 reward = 135.781
# Episode 3107 reward = 259.054
# Episode 3108 reward = 235.871
# Episode 3109 reward = 199.15
# Episode 3110 reward = 193.236
# ---------------------------
# Last 10 episode avg = 194.321
# ---------------------------
# Episode 3111 reward = -196.97
# Episode 3112 reward = 194.539
# Episode 3113 reward = -143.322
# Episode 3114 reward = 224.543
# Episode 3115 reward = 149.311
# Episode 3116 reward = 230.683
# Episode 3117 reward = -69.6973
# Episode 3118 reward = 179.401
# Episode 3119 reward = 155.718
# Episode 3120 reward = 63.7606
# ---------------------------
# Last 10 episode avg = 91.7441
# ---------------------------
# Episode 3121 reward = 158.509
# Episode 3122 reward = 59.091
# Episode 3123 reward = 183.127
# Episode 3124 reward = 194.151
# Episode 3125 reward = 165.348
# Episode 3126 reward = 210.987
# Episode 3127 reward = 246.298
# Episode 3128 reward = -58.004
# Episode 3129 reward = 206.558
# Episode 3130 reward = 202.209
# ---------------------------
# Last 10 episode avg = 142.983
# ---------------------------
# Episode 3131 reward = 153.223
# Episode 3132 reward = -80.3338
# Episode 3133 reward = 195.444
# Episode 3134 reward = 293.24
# Episode 3135 reward = -118.658
# Episode 3136 reward = 165.585
# Episode 3137 reward = -100.236
# Episode 3138 reward = -54.5278
# Episode 3139 reward = -165.478
# Episode 3140 reward = 0.51607
# ---------------------------
# Last 10 episode avg = 49.0466
# ---------------------------
# Episode 3141 reward = 33.2593
# Episode 3142 reward = -158.302
# Episode 3143 reward = 237.646
# Episode 3144 reward = 119.426
# Episode 3145 reward = -35.4107
# Episode 3146 reward = 198.712
# Episode 3147 reward = -106.419
# Episode 3148 reward = 189.603
# Episode 3149 reward = 125.041
# Episode 3150 reward = 214.47
# ---------------------------
# Last 10 episode avg = 60.4072
# ---------------------------
# Episode 3151 reward = -124.901
# Episode 3152 reward = 193.503
# Episode 3153 reward = 205.043
# Episode 3154 reward = 185.581
# Episode 3155 reward = 181.368
# Episode 3156 reward = 206.1
# Episode 3157 reward = 120.919
# Episode 3158 reward = 66.4074
# Episode 3159 reward = -110.169
# Episode 3160 reward = 186.241
# ---------------------------
# Last 10 episode avg = 113.832
# ---------------------------
# Episode 3161 reward = 195.241
# Episode 3162 reward = 174.293
# Episode 3163 reward = 137.303
# Episode 3164 reward = 127.011
# Episode 3165 reward = 165.913
# Episode 3166 reward = -121.022
# Episode 3167 reward = -37.8473
# Episode 3168 reward = 250.507
# Episode 3169 reward = -49.3445
# Episode 3170 reward = 2.34234
# ---------------------------
# Last 10 episode avg = 102.83
# ---------------------------
# Episode 3171 reward = 195.548
# Episode 3172 reward = 213.915
# Episode 3173 reward = -50.3314
# Episode 3174 reward = 186.989
# Episode 3175 reward = 137.128
# Episode 3176 reward = -18.9662
# Episode 3177 reward = 141.581
# Episode 3178 reward = 198.762
# Episode 3179 reward = 200.519
# Episode 3180 reward = 212.241
# ---------------------------
# Last 10 episode avg = 120.749
# ---------------------------
# Episode 3181 reward = -43.7808
# Episode 3182 reward = 236.922
# Episode 3183 reward = 215.567
# Episode 3184 reward = -202.517
# Episode 3185 reward = -66.9473
# Episode 3186 reward = 233.306
# Episode 3187 reward = 230.684
# Episode 3188 reward = 295.363
# Episode 3189 reward = 110.03
# Episode 3190 reward = 34.4855
# ---------------------------
# Last 10 episode avg = 122.087
# ---------------------------
# Episode 3191 reward = 217.811
# Episode 3192 reward = -180.04
# Episode 3193 reward = -35.7607
# Episode 3194 reward = 253.614
# Episode 3195 reward = 246.945
# Episode 3196 reward = 242.216
# Episode 3197 reward = -55.7809
# Episode 3198 reward = 178.591
# Episode 3199 reward = -80.5379
# Episode 3200 reward = 223.489
# ---------------------------
# Last 10 episode avg = 82.1544
# ---------------------------
# Episode 3201 reward = 51.679
# Episode 3202 reward = -143.943
# Episode 3203 reward = 148.667
# Episode 3204 reward = 152.243
# Episode 3205 reward = 92.2957
# Episode 3206 reward = -93.7257
# Episode 3207 reward = 171.046
# Episode 3208 reward = 109.08
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-d7b59740ba38> in <module>()
#       5     while current_step < max_steps_per_epoch and not epoch_done:
#       6         # Choose an action using the greedy-epsilon policy
# ----> 7         action = choose_action(state, epsilon)
#       8         new_state, reward, epoch_done, info = env.step(action)
#       9         total_reward[epoch] = total_reward[epoch] + reward
#
# <ipython-input-8-aaa3f5b71eb5> in choose_action(state, epsilon)
#       8         action = np.floor(np.random.randint(nb_actions))
#       9     else:
# ---> 10         action = get_best_action(state)
#      11     return int(action)
#
# <ipython-input-6-30317433225c> in get_best_action(state)
#       3         argMax(Q(nxt_state, all_actions))
#       4     """
# ----> 5     state_q_values = forward_pass(state)
#       6     return np.argmax(state_q_values)
#
# <ipython-input-5-807d3d89208a> in forward_pass(state)
#       2     input = np.empty([1, 1, 8])
#       3     input[0][0] = state
# ----> 4     return model.predict(input)[0]
#
# /anaconda3/lib/python3.6/site-packages/keras/models.py in predict(self, x, batch_size, verbose, steps)
#    1062             self.build()
#    1063         return self.model.predict(x, batch_size=batch_size, verbose=verbose,
# -> 1064                                   steps=steps)
#    1065
#    1066     def predict_on_batch(self, x):
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1833         f = self.predict_function
#    1834         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1835                                   verbose=verbose, steps=steps)
#    1836
#    1837     def train_on_batch(self, x, y,
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1329                     ins_batch[i] = ins_batch[i].toarray()
#    1330
# -> 1331                 batch_outs = f(ins_batch)
#    1332                 if not isinstance(batch_outs, list):
#    1333                     batch_outs = [batch_outs]
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
print("Max episode reward = {}".format(np.max(total_reward)))
model.save('dqn.h5')

# %%
for i_episode in range(20):
    observation = env.reset()
    for t in range(1000):
        
        action = choose_action(observation, 0.0)
        observation, reward, done, info = env.step(action)
        env.render()
        if done:
            print("Episode finished after {} timesteps\n Last Reward: {}".format(t+1, reward))
            break

env.close()
# Out:
# Episode finished after 242 timesteps
#  Last Reward: 100
# Episode finished after 472 timesteps
#  Last Reward: 100
# Episode finished after 353 timesteps
#  Last Reward: 100
# Episode finished after 286 timesteps
#  Last Reward: 100
# Episode finished after 354 timesteps
#  Last Reward: 100
# Episode finished after 351 timesteps
#  Last Reward: 100
# Episode finished after 256 timesteps
#  Last Reward: 100
# Episode finished after 143 timesteps
#  Last Reward: -100
# Episode finished after 293 timesteps
#  Last Reward: 100
# Episode finished after 381 timesteps
#  Last Reward: 100
# Episode finished after 297 timesteps
#  Last Reward: 100
# Episode finished after 411 timesteps
#  Last Reward: 100
# Episode finished after 370 timesteps
#  Last Reward: 100
# Episode finished after 342 timesteps
#  Last Reward: 100
# Episode finished after 397 timesteps
#  Last Reward: 100
# Episode finished after 387 timesteps
#  Last Reward: 100
# Episode finished after 391 timesteps
#  Last Reward: 100
# Episode finished after 1000 timesteps
#  Last Reward: -0.023770310427565278
# Episode finished after 460 timesteps
#  Last Reward: 100
# Episode finished after 646 timesteps
#  Last Reward: 100

# %%
model = load_model('dqn.h5')
